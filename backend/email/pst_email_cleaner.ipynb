# %%
# !pip install pytz  
# pip install unicodecsv
# Out:
# Requirement already satisfied: pytz in c:\users\v-samomin\appdata\local\programs\python\python310\lib\site-packages (2024.1)
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pywintypes  
from datetime import datetime
import re  
from bs4 import BeautifulSoup, NavigableString
import html 
import os
from dateutil import parser
  
def format_pywintypes_datetime(pywin_dt):  
    dt = datetime.fromtimestamp(pywin_dt.timestamp(), pywin_dt.tzinfo)    
    formatted_dt = dt.strftime("%A, %B %d, %Y %I:%M %p")  
      
    return formatted_dt    
  
def convert_to_timestamp(datetime_str):
    datetime_str = datetime_str.strip()
    
    # Dictionary to translate Finnish to English
    finnish_to_english = {
        'maanantai': 'Monday', 'tiistai': 'Tuesday', 'keskiviikko': 'Wednesday', 
        'torstai': 'Thursday', 'perjantai': 'Friday', 'lauantai': 'Saturday', 
        'sunnuntai': 'Sunday', 'tammikuuta': 'January', 'helmikuuta': 'February', 
        'maaliskuuta': 'March', 'huhtikuuta': 'April', 'toukokuuta': 'May', 
        'kesäkuuta': 'June', 'heinäkuuta': 'July', 'elokuuta': 'August', 
        'syyskuuta': 'September', 'lokakuuta': 'October', 'marraskuuta': 'November', 
        'joulukuuta': 'December'
    }
    
    # Replace Finnish words with English words
    for finnish, english in finnish_to_english.items():
        datetime_str = datetime_str.replace(finnish, english)
    
    try:
        # Try parsing with dateutil.parser first
        datetime_obj = parser.parse(datetime_str)
        return datetime_obj
    except ValueError:
        # Try different format patterns
        formats = [
            '%A %d. %B %Y %H.%M',  # Original format
            '%A, %d %B %Y %H.%M',  # Format with comma
            '%Y年%m月%d日%H:%M',   # Japanese format
            '%A, %d %B %Y %H:%M',  # Format with colon
            '%d %B %Y %H.%M',      # Format without weekday
            '%d %B %Y %H:%M'       # Format without weekday, with colon
        ]
        
        for date_format in formats:
            try:
                datetime_obj = datetime.strptime(datetime_str, date_format)
                return datetime_obj
            except ValueError:
                continue
        
        # If all formats fail, try handling special cases
        try:
            # Handle case where dots and colons might be mixed
            datetime_str = datetime_str.replace('.', ':')
            datetime_obj = datetime.strptime(datetime_str, '%A, %d %B %Y %H:%M')
            return datetime_obj
        except ValueError:
            try:
                # Handle case where dots and colons might be mixed (without weekday)
                datetime_obj = datetime.strptime(datetime_str, '%d %B %Y %H:%M')
                return datetime_obj
            except ValueError as e:
                print(f"Error parsing datetime string: {e}")
                return None

def process_element(element, depth=0):
    if isinstance(element, NavigableString):
        return html.unescape(str(element)).strip()

    if element.name == 'br':
        return '\n'

    if element.name in ['p', 'div']:
        return '\n\n' + ''.join(process_element(child, depth + 1) for child in element.children).strip() + '\n\n'

    if element.name in ['h1', 'h2', 'h3', 'h4', 'h5', 'h6']:
        return '\n\n' + ''.join(process_element(child, depth + 1) for child in element.children).strip().upper() + '\n\n'

    if 'src' in element.attrs and element['src'].startswith('cid:'):
        cid = element['src'].split(':', 1)[1]
        return f'\n\n[cid:{cid}]\n'

    # Recursively process child elements
    return ''.join(process_element(child, depth + 1) for child in element.children)


def clean_email_content(text):
    # Remove HTML tags
    clean = re.sub(r'<[^>]+>', '', text)
    
    # Remove special characters and extra whitespace
    clean = re.sub(r'[\r\n\t]+', '\n', clean)
    clean = re.sub(r'\[if.*?\].*?\[endif\]', '', clean, flags=re.DOTALL)
    clean = re.sub(r'\[cid:.*?\]', '', clean)
    
    # # Remove extra newlines
    # clean = re.sub(r'\n+', '\n', clean)
    
    # Strip leading and trailing whitespace
    clean = clean.strip()
    
    return clean
  
def html_to_clean_text_with_ordered_cids(email_obj): 
    Hbody = email_obj.HTMLBody 
    # Parse the HTML  
    soup = BeautifulSoup(Hbody, 'html.parser')

    # Remove style and script tags
    for tag in soup(['style', 'script']):
        tag.decompose()

    # Function to process each element

    # Process the entire body
    raw_text = process_element(soup.body)

    # # Clean up the text
    clean_text = re.sub(r'\n{3,}', '\n\n', raw_text)  # Replace 3 or more newlines with 2
    clean_text = re.sub(r' +', ' ', clean_text)  # Remove extra spaces
    clean_text = clean_text.strip()  # Remove leading/trailing whitespace

    # Add extra newline before "From:" to separate email threads
    clean_text = re.sub(r'(\nFrom:)', r'-------------\1', clean_text)

    clean_text = f"""
From:{email_obj.SenderName}
Sent:{format_pywintypes_datetime(email_obj.SentOn)}
To:{email_obj.To}
Cc:{email_obj.CC}
Subject:{email_obj.Subject}

{clean_text}
"""
      
    return clean_text

def extract_email_info(email_text, folder_path=None):
    email_info = {}

    # Extract From
    from_match = re.search(r'From:(.*?)\n', email_text, re.DOTALL)
    if from_match:
        from_line = from_match.group(1).strip()
        name_email_match = re.search(r'(.*?)\s*<([^>]+)>', from_line)
        if name_email_match:
            email_info['from'] = {
                'name': name_email_match.group(1).strip(),
                'email': name_email_match.group(2).strip()
            }
        else:
            email_info['from'] = {
                'name': from_line,
                'email': None
            }

    # Extract Sent time
    sent_match = re.search(r'Sent:(.*?)\n', email_text, re.DOTALL)
    if sent_match:
        email_info['time'] = sent_match.group(1).strip()
        email_info['time_py'] = convert_to_timestamp(email_info['time'])

    # Extract To
    to_match = re.search(r'To:(.*?)\n', email_text, re.DOTALL)
    if to_match:
        to_list = to_match.group(1).strip().split(';')
        email_info['to'] = []
        for to in to_list:
            to_name_email = re.search(r'(.*?)\s*<([^>]+)>', to.strip())
            if to_name_email:
                email_info['to'].append({
                    'name': to_name_email.group(1).strip(),
                    'email': to_name_email.group(2).strip()
                })
            else:
                email_info['to'].append({
                    'name': to.strip(),
                    'email': None
                })

    # Extract Cc
    cc_match = re.search(r'Cc:(.*?)\n', email_text, re.DOTALL)
    if cc_match:
        cc_list = cc_match.group(1).strip().split(';')
        email_info['cc'] = []
        for cc in cc_list:
            cc_name_email = re.search(r'(.*?)\s*<([^>]+)>', cc.strip())
            if cc_name_email:
                email_info['cc'].append({
                    'name': cc_name_email.group(1).strip(),
                    'email': cc_name_email.group(2).strip()
                })
            else:
                email_info['cc'].append({
                    'name': cc.strip(),
                    'email': None
                })

    # Extract Subject
    subject_match = re.search(r'Subject:(.*?)\n', email_text, re.DOTALL)
    if subject_match:
        email_info['subject'] = subject_match.group(1).strip()

    # Extract Content and Attachments
    content_match = re.search(r'Subject:.*?\n(.*)', email_text, re.DOTALL)
    if content_match:
        content = content_match.group(1).strip()
        attachments = re.findall(r'\[cid:(.*?)@[^\]]*\]', content)
        for attachment in attachments:
            content = re.sub(rf'\[cid:{re.escape(attachment)}@[^\]]*\]', f'****{attachment}****', content)
        email_info['email_content'] = clean_email_content(content)
        email_info['attachment'] = attachments if attachments else None
        if email_info['attachment'] is not None and folder_path:
            current_attachment_path = [f"attachments\\{folder_path}\\{i}" for i in email_info['attachment']]
            email_info['attachment'] = current_attachment_path

    return email_info

def get_email_list(clean_text, folder_path=None):  
    emails = clean_text.split('-------------')
    emails = [email for email in emails if email]  
    
    # Parse each email and store in a list of dictionaries  
    email_list = [extract_email_info(email, folder_path) for email in emails]
    return email_list



def custom_encoder(obj):  
        if isinstance(obj, datetime):  
            return obj.isoformat()  # Convert datetime to ISO 8601 string  
        raise TypeError(f"Object of type {type(obj)} is not JSON serializable")

def custom_decoder(dct):
    for key, value in dct.items():
        if key == 'time_py' and isinstance(value, str):
            try:
                dct[key] = datetime.fromisoformat(value)
            except ValueError:
                pass  # If it's not a valid ISO format, leave it as is
    return dct

def process_new_dict(existing_list, item):
    new_subject = item.Subject
    new_time = item.SentOn
    for existing_dict in existing_list:
        if existing_dict.Subject == new_subject:
            existing_time = existing_dict.SentOn
            if new_time > existing_time:
                return 'REPLACE', existing_dict
            else:
                return 'IGNORE', None
    return 'ADD', None

# %%
# import win32com.client
# import json

# def find_pst_folder(OutlookObj, pst_filepath) :
#     for Store in OutlookObj.Stores :
#         if Store.IsDataFileStore and Store.FilePath == pst_filepath :
#             return Store.GetRootFolder()
#     return None

# def enumerate_folders(FolderObj) :
#     for ChildFolder in FolderObj.Folders :
#         enumerate_folders(ChildFolder)
#     iterate_messages(FolderObj)

# def iterate_messages(FolderObj, save_path):
#     attachment_path = f"{save_path}\\attachments"
#     for index,item in enumerate(FolderObj.Items):
#         try:
#             folder_path = f"{attachment_path}\\{index}"
#             clean_email = html_to_clean_text_with_ordered_cids(item)
            

#             # clean_email_.append(clean_email) 
#             email_list = get_email_list(clean_email, index)
            
#             count_attachments = item.Attachments.Count
#             if count_attachments > 0 :
#                 os.mkdir(folder_path)
#                 for att in range(count_attachments) :
#                     item.Attachments.Item(att + 1).SaveAsFile(folder_path +"\\"+item.Attachments.Item(att + 1).FileName)

        
#             with open(f"{save_path}\data.json", 'a') as json_file:
#                 json_file.write(json.dumps(email_list, default=custom_encoder) + '\n')
#             print('completed', index)
            
#         except:
#             print('skipped', index)
        

    

# Outlook = win32com.client.Dispatch("Outlook.Application").GetNamespace("MAPI")


# pst = r"C:\Users\v-samomin\Downloads\2024_PDMLink_data\2024_PDMLink_data.pst"
# save_path = r"C:\Users\v-samomin\Downloads\2024_PDMLink_data"
# Outlook.AddStore(pst)
# PSTFolderObj = find_pst_folder(Outlook,pst)

# full_email = iterate_messages(PSTFolderObj, save_path)

# Outlook.RemoveStore(PSTFolderObj)

# %%
# # function to get the target folder

# import win32com.client
# import pywintypes
# import time
# import os

# def list_folders(folder, indent=0):
#     """Recursively list all folders in the PST"""
#     try:
#         print('  ' * indent + f"Folder: {folder.Name}")
#         for subfolder in folder.Folders:
#             list_folders(subfolder, indent + 1)
#     except Exception as e:
#         print(f"Error listing folder {folder.Name}: {e}")

# def explore_pst_structure(outlook_namespace, pst_path):
#     """Explore and print the PST file structure"""
#     try:
#         # List all stores
#         print("\nListing all available stores:")
#         for store in outlook_namespace.Stores:
#             try:
#                 print(f"Store: {store.DisplayName}")
#                 print(f"File Path: {getattr(store, 'FilePath', 'N/A')}")
#             except Exception as e:
#                 print(f"Error accessing store details: {e}")

#         # Find our specific PST
#         print("\nAttempting to find specific PST file...")
#         for store in outlook_namespace.Stores:
#             try:
#                 if hasattr(store, 'FilePath') and store.FilePath == pst_path:
#                     print(f"Found PST: {store.DisplayName}")
#                     root = store.GetRootFolder()
#                     print("\nFolder structure:")
#                     list_folders(root)
#                     return root
#             except Exception as e:
#                 print(f"Error checking store: {e}")
                
#         print("PST file not found in mounted stores")
#         return None
#     except Exception as e:
#         print(f"Error exploring PST structure: {e}")
#         return None

# try:
#     # Create Outlook objects
#     print("Initializing Outlook...")
#     outlook_app = win32com.client.Dispatch("Outlook.Application")
#     outlook_namespace = outlook_app.GetNamespace("MAPI")
    
#     pst_path = r"C:\Users\v-samomin\Downloads\2024_PDMLink_data\2024_PDMLink_data.pst"
    
#     # First try to find if PST is already mounted
#     print("\nChecking if PST is already mounted...")
#     root_folder = explore_pst_structure(outlook_namespace, pst_path)
    
#     if not root_folder:
#         print("\nAttempting to mount PST file...")
#         try:
#             outlook_namespace.AddStore(pst_path)
#             time.sleep(3)  # Give it time to mount
#             print("PST mounted, exploring structure...")
#             root_folder = explore_pst_structure(outlook_namespace, pst_path)
#         except Exception as e:
#             print(f"Error mounting PST: {e}")
    
#     if root_folder:
#         print("\nSuccessfully accessed PST. Attempting to read contents...")
#         try:
#             # Try to access the first few items
#             for folder in root_folder.Folders:
#                 print(f"\nAccessing folder: {folder.Name}")
#                 try:
#                     items = folder.Items
#                     item_count = items.Count
#                     print(f"Number of items in folder: {item_count}")
                    
#                     # Try to read first item if any exist
#                     if item_count > 0:
#                         first_item = items.GetFirst()
#                         print(f"First item subject: {first_item.Subject}")
#                 except Exception as e:
#                     print(f"Error accessing folder contents: {e}")
#         except Exception as e:
#             print(f"Error reading PST contents: {e}")
#     else:
#         print("\nFailed to access PST file structure")

# except Exception as e:
#     print(f"General error: {e}")

# finally:
#     print("\nScript completed")

# %%
import win32com.client
import json
import os
import time

def find_pst_folder(outlook_namespace, pst_filepath, target_folder="2024_Inbox"):
    """Find specific folder in PST file"""
    for store in outlook_namespace.Stores:
        if hasattr(store, 'FilePath') and store.FilePath == pst_filepath:
            root = store.GetRootFolder()
            # Navigate through folders to find target folder
            for folder in root.Folders:
                if folder.Name == target_folder:
                    return folder, store
    return None, None

def iterate_messages(FolderObj, save_path):
    """Your existing message processing function - kept unchanged"""
    attachment_path = f"{save_path}\\attachments"
    for index, item in enumerate(FolderObj.Items):
        try:
            folder_path = f"{attachment_path}\\{index}"
            clean_email = html_to_clean_text_with_ordered_cids(item)
            
            email_list = get_email_list(clean_email, index)
            
            count_attachments = item.Attachments.Count
            if count_attachments > 0:
                os.mkdir(folder_path)
                for att in range(count_attachments):
                    item.Attachments.Item(att + 1).SaveAsFile(folder_path + "\\" + item.Attachments.Item(att + 1).FileName)
        
            with open(f"{save_path}\\data.json", 'a') as json_file:
                json_file.write(json.dumps(email_list, default=custom_encoder) + '\n')
            print('completed', index)
            
        except Exception as e:
            print('skipped', index)
            print(e)

def process_pst(pst_path, save_path):
    try:
        print("Initializing Outlook...")
        outlook_app = win32com.client.Dispatch("Outlook.Application")
        outlook_namespace = outlook_app.GetNamespace("MAPI")
        
        # First check if folder is already accessible
        target_folder, store = find_pst_folder(outlook_namespace, pst_path)
        
        # If not found, try mounting the PST
        if not target_folder:
            print("Target folder not found. Attempting to mount PST...")
            try:
                outlook_namespace.AddStore(pst_path)
                time.sleep(3)  # Give it time to mount
                target_folder, store = find_pst_folder(outlook_namespace, pst_path)
            except Exception as e:
                print(f"Error mounting PST: {e}")
                return
        
        if target_folder:
            print(f"Successfully accessed folder: {target_folder.Name}")
            print(f"Number of items: {target_folder.Items.Count}")
            
            # Create attachments directory if it doesn't exist
            os.makedirs(f"{save_path}\\attachments", exist_ok=True)
            
            # Process messages
            iterate_messages(target_folder, save_path)
            
            # Clean up
            if store:
                outlook_namespace.RemoveStore(store.GetRootFolder())
        else:
            print("Failed to access target folder")
            
    except Exception as e:
        print(f"General error: {e}")
    
    finally:
        print("Processing completed")

if __name__ == "__main__":
    pst_path = r"C:\Users\v-samomin\Downloads\2024_PDMLink_data\2024_PDMLink_data.pst"
    save_path = r"C:\Users\v-samomin\Downloads\2024_PDMLink_data"
    
    process_pst(pst_path, save_path)

#base code

# %%
import json
def remove_duplicate_lists(input_file, output_file):
    # Iterate over each list of dicts in the main list
    with open(input_file, 'r') as file:
        list_of_lists = [json.loads(line, object_hook=custom_decoder) for line in file]
    i = 0
    while i < len(list_of_lists):
        current_list = list_of_lists[i]  # Current list of dicts
        if not current_list:  # Skip if the list is empty
            i += 1
            continue
        
        # Get the "email_content" of the last dictionary in the current list
        selected_email_content = current_list[-1].get('email_content', None)
        selected_subject = current_list[-1].get('subject', None)
        selected_time_py = current_list[-1].get('time_py', None)
        


        
        # if not selected_email_content:
        #     i += 1
        #     continue
        
        # Iterate over the remaining elements in the list
        j = i + 1
        while j < len(list_of_lists):
            next_list = list_of_lists[j]
            
            # Check if the "email_content" of the last dictionary in the next list matches
            next_email_content = next_list[-1].get('email_content', None)
            next_subject = next_list[-1].get('subject', None)
            
            next_time_py = next_list[-1].get('time_py', None)

            if (next_subject == selected_subject and next_time_py == selected_time_py) or (next_email_content == selected_email_content):
                # Remove the duplicate list if found
                list_of_lists.pop(j)
            else:
                j += 1
        
        # Move to the next element
        i += 1

    with open(output_file, 'w') as file:
        for email_list in list_of_lists:
            json.dump(email_list, file, default=custom_encoder)
            file.write('\n')
    
    return list_of_lists



input_file = r"C:\Users\v-samomin\Downloads\2024_PDMLink_data\data.json"

output_file = r"C:\Users\v-samomin\Downloads\2024_PDMLink_data\data_cleaned_2.json"



result = remove_duplicate_lists(input_file, output_file)

# %%
import json
with open(r"C:\Users\v-samomin\Downloads\2024_PDMLink_data\data_cleaned_2.json", 'r') as file:
    list_of_lists = [json.loads(line, object_hook=custom_decoder) for line in file]

# %%
list_of_lists[0][0]['attachment']#[0].split('\\')[1]

# %%
attachments = []
for emails in list_of_lists:
    for email in emails:
        global email_
        email_ = email
        try:
            if email['attachment'] is not None:
                for attach in email['attachment']:
                        folder = attach.split('\\')[1]
                        if folder not in attachments:
                            attachments.append(folder)
        except:
             pass

# %%
import os
import shutil

# Path to the parent directory containing folders
parent_dir = r"C:\Users\v-samomin\Downloads\2024_PDMLink_data\attachments"

# List of folders to keep
folders_to_keep = attachments  # Add your folder names here

# Get a list of all directories in the parent directory
all_folders = [d for d in os.listdir(parent_dir) if os.path.isdir(os.path.join(parent_dir, d))]

# Iterate through all folders and delete those not in the 'folders_to_keep' list
for folder in all_folders:
    if folder not in folders_to_keep:
        folder_path = os.path.join(parent_dir, folder)
        try:
            shutil.rmtree(folder_path)  # Deletes the entire folder and its contents
            print(f"Deleted folder: {folder}")
        except Exception as e:
            print(f"Failed to delete {folder}: {e}")

print("Cleanup complete.")
# Out:
# Deleted folder: 0
# Deleted folder: 10
# Deleted folder: 100
# Deleted folder: 1000
# Deleted folder: 1001
# Deleted folder: 1002
# Deleted folder: 1004
# Deleted folder: 1006
# Deleted folder: 1007
# Deleted folder: 1008
# Deleted folder: 1009
# Deleted folder: 101
# Deleted folder: 1010
# Deleted folder: 1012
# Deleted folder: 1014
# Deleted folder: 1016
# Deleted folder: 1017
# Deleted folder: 1018
# Deleted folder: 1019
# Deleted folder: 102
# Deleted folder: 1020
# Deleted folder: 1021
# Deleted folder: 1022
# Deleted folder: 1023
# Deleted folder: 1024
# Deleted folder: 1025
# Deleted folder: 1026
# Deleted folder: 1028
# Deleted folder: 103
# Deleted folder: 1030
# Deleted folder: 1031
# Deleted folder: 1032
# Deleted folder: 1033
# Deleted folder: 1036
# Deleted folder: 1038
# Deleted folder: 1039
# Deleted folder: 104
# Deleted folder: 1041
# Deleted folder: 1042
# Deleted folder: 1044
# Deleted folder: 1045
# Deleted folder: 1046
# Deleted folder: 1049
# Deleted folder: 105
# Deleted folder: 1051
# Deleted folder: 1052
# Deleted folder: 1054
# Deleted folder: 1055
# Deleted folder: 1056
# Deleted folder: 1057
# Deleted folder: 1059
# Deleted folder: 106
# Deleted folder: 1060
# Deleted folder: 1061
# Deleted folder: 1067
# Deleted folder: 1068
# Deleted folder: 1069
# Deleted folder: 107
# Deleted folder: 1070
# Deleted folder: 1071
# Deleted folder: 1072
# Deleted folder: 1074
# Deleted folder: 1075
# Deleted folder: 1076
# Deleted folder: 1077
# Deleted folder: 1079
# Deleted folder: 1080
# Deleted folder: 1081
# Deleted folder: 1082
# Deleted folder: 1083
# Deleted folder: 1085
# Deleted folder: 1086
# Deleted folder: 1087
# Deleted folder: 1088
# Deleted folder: 109
# Deleted folder: 1091
# Deleted folder: 1096
# Deleted folder: 110
# Deleted folder: 1104
# Deleted folder: 1105
# Deleted folder: 1106
# Deleted folder: 1108
# Deleted folder: 1109
# Deleted folder: 1110
# Deleted folder: 1111
# Deleted folder: 1112
# Deleted folder: 1113
# Deleted folder: 1114
# Deleted folder: 1115
# Deleted folder: 1116
# Deleted folder: 1117
# Deleted folder: 1118
# Deleted folder: 1119
# Deleted folder: 1120
# Deleted folder: 1122
# Deleted folder: 1124
# Deleted folder: 1125
# Deleted folder: 1126
# Deleted folder: 113
# Deleted folder: 1132
# Deleted folder: 1133
# Deleted folder: 1134
# Deleted folder: 1135
# Deleted folder: 1136
# Deleted folder: 1137
# Deleted folder: 1138
# Deleted folder: 114
# Deleted folder: 1142
# Deleted folder: 1143
# Deleted folder: 1146
# Deleted folder: 1147
# Deleted folder: 1149
# Deleted folder: 1150
# Deleted folder: 1151
# Deleted folder: 1152
# Deleted folder: 1153
# Deleted folder: 1154
# Deleted folder: 1155
# Deleted folder: 1156
# Deleted folder: 1157
# Deleted folder: 1159
# Deleted folder: 1160
# Deleted folder: 1161
# Deleted folder: 1164
# Deleted folder: 1165
# Deleted folder: 1167
# Deleted folder: 1169
# Deleted folder: 1173
# Deleted folder: 1174
# Deleted folder: 1175
# Deleted folder: 1176
# Deleted folder: 1177
# Deleted folder: 1178
# Deleted folder: 1179
# Deleted folder: 1180
# Deleted folder: 1182
# Deleted folder: 1184
# Deleted folder: 1186
# Deleted folder: 1187
# Deleted folder: 1189
# Deleted folder: 1190
# Deleted folder: 1191
# Deleted folder: 1192
# Deleted folder: 1195
# Deleted folder: 1196
# Deleted folder: 1197
# Deleted folder: 1198
# Deleted folder: 1199
# Deleted folder: 12
# Deleted folder: 1200
# Deleted folder: 1201
# Deleted folder: 1202
# Deleted folder: 1203
# Deleted folder: 1204
# Deleted folder: 1206
# Deleted folder: 1207
# Deleted folder: 1208
# Deleted folder: 1209
# Deleted folder: 1210
# Deleted folder: 1211
# Deleted folder: 1212
# Deleted folder: 1214
# Deleted folder: 1216
# Deleted folder: 1217
# Deleted folder: 1218
# Deleted folder: 1219
# Deleted folder: 1220
# Deleted folder: 1221
# Deleted folder: 1223
# Deleted folder: 1224
# Deleted folder: 1225
# Deleted folder: 1229
# Deleted folder: 1231
# Deleted folder: 1232
# Deleted folder: 1234
# Deleted folder: 1235
# Deleted folder: 1236
# Deleted folder: 1237
# Deleted folder: 1238
# Deleted folder: 1239
# Deleted folder: 1240
# Deleted folder: 1241
# Deleted folder: 1242
# Deleted folder: 1243
# Deleted folder: 1244
# Deleted folder: 1246
# Deleted folder: 1248
# Deleted folder: 125
# Deleted folder: 1252
# Deleted folder: 1254
# Deleted folder: 1255
# Deleted folder: 1257
# Deleted folder: 1258
# Deleted folder: 1260
# Deleted folder: 1261
# Deleted folder: 1262
# Deleted folder: 1264
# Deleted folder: 1265
# Deleted folder: 1268
# Deleted folder: 1269
# Deleted folder: 1270
# Deleted folder: 1271
# Deleted folder: 1272
# Deleted folder: 1274
# Deleted folder: 1275
# Deleted folder: 1276
# Deleted folder: 1286
# Deleted folder: 1287
# Deleted folder: 1288
# Deleted folder: 1289
# Deleted folder: 1291
# Deleted folder: 1293
# Deleted folder: 1294
# Deleted folder: 1295
# Deleted folder: 13
# Deleted folder: 1301
# Deleted folder: 1303
# Deleted folder: 1304
# Deleted folder: 1305
# Deleted folder: 1307
# Deleted folder: 1309
# Deleted folder: 1311
# Deleted folder: 1312
# Deleted folder: 1313
# Deleted folder: 1314
# Deleted folder: 1315
# Deleted folder: 1316
# Deleted folder: 1317
# Deleted folder: 1318
# Deleted folder: 1319
# Deleted folder: 1320
# Deleted folder: 1321
# Deleted folder: 1324
# Deleted folder: 1325
# Deleted folder: 1326
# Deleted folder: 1328
# Deleted folder: 1329
# Deleted folder: 1330
# Deleted folder: 1331
# Deleted folder: 1332
# Deleted folder: 1333
# Deleted folder: 1334
# Deleted folder: 1335
# Deleted folder: 1336
# Deleted folder: 1337
# Deleted folder: 1339
# Deleted folder: 1340
# Deleted folder: 1342
# Deleted folder: 1343
# Deleted folder: 1344
# Deleted folder: 1345
# Deleted folder: 1346
# Deleted folder: 1347
# Deleted folder: 1348
# Deleted folder: 1349
# Deleted folder: 1350
# Deleted folder: 1351
# Deleted folder: 1353
# Deleted folder: 1354
# Deleted folder: 1355
# Deleted folder: 1356
# Deleted folder: 1359
# Deleted folder: 1364
# Deleted folder: 1367
# Deleted folder: 1368
# Deleted folder: 1370
# Deleted folder: 1371
# Deleted folder: 1372
# Deleted folder: 1373
# Deleted folder: 1374
# Deleted folder: 1375
# Deleted folder: 1376
# Deleted folder: 1377
# Deleted folder: 1378
# Deleted folder: 1380
# Deleted folder: 1381
# Deleted folder: 1382
# Deleted folder: 1383
# Deleted folder: 1384
# Deleted folder: 1389
# Deleted folder: 1390
# Deleted folder: 1391
# Deleted folder: 1392
# Deleted folder: 1393
# Deleted folder: 1395
# Deleted folder: 1397
# Deleted folder: 1398
# Deleted folder: 14
# Deleted folder: 1400
# Deleted folder: 1401
# Deleted folder: 1403
# Deleted folder: 1404
# Deleted folder: 1405
# Deleted folder: 1406
# Deleted folder: 1407
# Deleted folder: 1412
# Deleted folder: 1414
# Deleted folder: 1415
# Deleted folder: 1416
# Deleted folder: 1418
# Deleted folder: 1419
# Deleted folder: 1420
# Deleted folder: 1421
# Deleted folder: 1426
# Deleted folder: 1427
# Deleted folder: 1428
# Deleted folder: 1429
# Deleted folder: 143
# Deleted folder: 1430
# Deleted folder: 1432
# Deleted folder: 1433
# Deleted folder: 1436
# Deleted folder: 1438
# Deleted folder: 1439
# Deleted folder: 1440
# Deleted folder: 1441
# Deleted folder: 1442
# Deleted folder: 1443
# Deleted folder: 1444
# Deleted folder: 1446
# Deleted folder: 1449
# Deleted folder: 1450
# Deleted folder: 1451
# Deleted folder: 1452
# Deleted folder: 1453
# Deleted folder: 1455
# Deleted folder: 1456
# Deleted folder: 1457
# Deleted folder: 1459
# Deleted folder: 1460
# Deleted folder: 1461
# Deleted folder: 1462
# Deleted folder: 1464
# Deleted folder: 1471
# Deleted folder: 1472
# Deleted folder: 1473
# Deleted folder: 1474
# Deleted folder: 1475
# Deleted folder: 1476
# Deleted folder: 1477
# Deleted folder: 1478
# Deleted folder: 1480
# Deleted folder: 1481
# Deleted folder: 1482
# Deleted folder: 1483
# Deleted folder: 1485
# Deleted folder: 1486
# Deleted folder: 1487
# Deleted folder: 1489
# Deleted folder: 149
# Deleted folder: 1491
# Deleted folder: 1492
# Deleted folder: 1496
# Deleted folder: 1498
# Deleted folder: 1499
# Deleted folder: 15
# Deleted folder: 150
# Deleted folder: 1501
# Deleted folder: 1502
# Deleted folder: 1509
# Deleted folder: 151
# Deleted folder: 1510
# Deleted folder: 1511
# Deleted folder: 1512
# Deleted folder: 1513
# Deleted folder: 1514
# Deleted folder: 1515
# Deleted folder: 1516
# Deleted folder: 1518
# Deleted folder: 1519
# Deleted folder: 152
# Deleted folder: 1520
# Deleted folder: 1521
# Deleted folder: 1522
# Deleted folder: 1523
# Deleted folder: 1524
# Deleted folder: 1525
# Deleted folder: 1527
# Deleted folder: 1528
# Deleted folder: 1529
# Deleted folder: 153
# Deleted folder: 1530
# Deleted folder: 1531
# Deleted folder: 1532
# Deleted folder: 1533
# Deleted folder: 1534
# Deleted folder: 1535
# Deleted folder: 1536
# Deleted folder: 1537
# Deleted folder: 1538
# Deleted folder: 1539
# Deleted folder: 154
# Deleted folder: 1542
# Deleted folder: 1543
# Deleted folder: 1545
# Deleted folder: 1546
# Deleted folder: 1547
# Deleted folder: 1548
# Deleted folder: 1549
# Deleted folder: 155
# Deleted folder: 1551
# Deleted folder: 1552
# Deleted folder: 1553
# Deleted folder: 1554
# Deleted folder: 1555
# Deleted folder: 1556
# Deleted folder: 1558
# Deleted folder: 1559
# Deleted folder: 156
# Deleted folder: 1560
# Deleted folder: 1561
# Deleted folder: 1562
# Deleted folder: 1564
# Deleted folder: 1565
# Deleted folder: 1566
# Deleted folder: 1567
# Deleted folder: 1569
# Deleted folder: 157
# Deleted folder: 1570
# Deleted folder: 1572
# Deleted folder: 1573
# Deleted folder: 1574
# Deleted folder: 1575
# Deleted folder: 1576
# Deleted folder: 1577
# Deleted folder: 1578
# Deleted folder: 1579
# Deleted folder: 1580
# Deleted folder: 1581
# Deleted folder: 1582
# Deleted folder: 1584
# Deleted folder: 1585
# Deleted folder: 1586
# Deleted folder: 1588
# Deleted folder: 159
# Deleted folder: 1590
# Deleted folder: 1591
# Deleted folder: 1592
# Deleted folder: 1593
# Deleted folder: 1595
# Deleted folder: 1596
# Deleted folder: 1597
# Deleted folder: 1598
# Deleted folder: 1599
# Deleted folder: 160
# Deleted folder: 1600
# Deleted folder: 1601
# Deleted folder: 1602
# Deleted folder: 1603
# Deleted folder: 1604
# Deleted folder: 1606
# Deleted folder: 1608
# Deleted folder: 1609
# Deleted folder: 1610
# Deleted folder: 1611
# Deleted folder: 1612
# Deleted folder: 1615
# Deleted folder: 1616
# Deleted folder: 1617
# Deleted folder: 1618
# Deleted folder: 1619
# Deleted folder: 162
# Deleted folder: 1620
# Deleted folder: 1621
# Deleted folder: 1622
# Deleted folder: 1623
# Deleted folder: 1624
# Deleted folder: 1626
# Deleted folder: 1627
# Deleted folder: 1630
# Deleted folder: 1631
# Deleted folder: 1632
# Deleted folder: 1633
# Deleted folder: 1634
# Deleted folder: 1635
# Deleted folder: 1636
# Deleted folder: 1637
# Deleted folder: 1638
# Deleted folder: 1639
# Deleted folder: 1640
# Deleted folder: 1643
# Deleted folder: 1644
# Deleted folder: 1645
# Deleted folder: 1646
# Deleted folder: 1647
# Deleted folder: 1648
# Deleted folder: 1649
# Deleted folder: 1653
# Deleted folder: 1655
# Deleted folder: 1656
# Deleted folder: 1657
# Deleted folder: 1658
# Deleted folder: 1659
# Deleted folder: 1660
# Deleted folder: 1661
# Deleted folder: 1662
# Deleted folder: 1663
# Deleted folder: 1664
# Deleted folder: 1665
# Deleted folder: 1666
# Deleted folder: 1668
# Deleted folder: 1669
# Deleted folder: 1670
# Deleted folder: 1671
# Deleted folder: 1672
# Deleted folder: 1673
# Deleted folder: 1676
# Deleted folder: 1677
# Deleted folder: 1678
# Deleted folder: 1679
# Deleted folder: 168
# Deleted folder: 1680
# Deleted folder: 1681
# Deleted folder: 1682
# Deleted folder: 1683
# Deleted folder: 1684
# Deleted folder: 1686
# Deleted folder: 1689
# Deleted folder: 169
# Deleted folder: 1690
# Deleted folder: 1691
# Deleted folder: 1693
# Deleted folder: 1694
# Deleted folder: 1695
# Deleted folder: 1696
# Deleted folder: 1697
# Deleted folder: 1698
# Deleted folder: 1699
# Deleted folder: 17
# Deleted folder: 170
# Deleted folder: 1700
# Deleted folder: 1702
# Deleted folder: 1705
# Deleted folder: 1708
# Deleted folder: 1709
# Deleted folder: 1710
# Deleted folder: 1711
# Deleted folder: 1712
# Deleted folder: 1713
# Deleted folder: 1714
# Deleted folder: 1716
# Deleted folder: 1720
# Deleted folder: 1721
# Deleted folder: 1722
# Deleted folder: 1723
# Deleted folder: 1724
# Deleted folder: 1725
# Deleted folder: 1726
# Deleted folder: 1728
# Deleted folder: 1731
# Deleted folder: 1732
# Deleted folder: 1735
# Deleted folder: 1736
# Deleted folder: 1738
# Deleted folder: 1740
# Deleted folder: 1741
# Deleted folder: 1743
# Deleted folder: 1744
# Deleted folder: 1745
# Deleted folder: 1746
# Deleted folder: 1747
# Deleted folder: 1748
# Deleted folder: 1749
# Deleted folder: 1750
# Deleted folder: 1751
# Deleted folder: 1753
# Deleted folder: 1754
# Deleted folder: 1755
# Deleted folder: 1757
# Deleted folder: 1758
# Deleted folder: 1759
# Deleted folder: 1760
# Deleted folder: 1761
# Deleted folder: 1762
# Deleted folder: 1764
# Deleted folder: 1765
# Deleted folder: 1766
# Deleted folder: 1767
# Deleted folder: 1769
# Deleted folder: 1770
# Deleted folder: 1771
# Deleted folder: 1772
# Deleted folder: 1773
# Deleted folder: 1774
# Deleted folder: 1775
# Deleted folder: 1776
# Deleted folder: 1777
# Deleted folder: 1780
# Deleted folder: 1782
# Deleted folder: 1784
# Deleted folder: 1785
# Deleted folder: 1786
# Deleted folder: 1787
# Deleted folder: 1788
# Deleted folder: 1789
# Deleted folder: 1790
# Deleted folder: 1791
# Deleted folder: 1792
# Deleted folder: 1794
# Deleted folder: 1795
# Deleted folder: 1796
# Deleted folder: 1797
# Deleted folder: 1798
# Deleted folder: 1799
# Deleted folder: 18
# Deleted folder: 1800
# Deleted folder: 1802
# Deleted folder: 1803
# Deleted folder: 1804
# Deleted folder: 1805
# Deleted folder: 1808
# Deleted folder: 1809
# Deleted folder: 1812
# Deleted folder: 1813
# Deleted folder: 1814
# Deleted folder: 1815
# Deleted folder: 1816
# Deleted folder: 1817
# Deleted folder: 1819
# Deleted folder: 1821
# Deleted folder: 1822
# Deleted folder: 1823
# Deleted folder: 1828
# Deleted folder: 1833
# Deleted folder: 1835
# Deleted folder: 1836
# Deleted folder: 1837
# Deleted folder: 1838
# Deleted folder: 1846
# Deleted folder: 1847
# Deleted folder: 1848
# Deleted folder: 1849
# Deleted folder: 1851
# Deleted folder: 1852
# Deleted folder: 1853
# Deleted folder: 1854
# Deleted folder: 1855
# Deleted folder: 1860
# Deleted folder: 1861
# Deleted folder: 1862
# Deleted folder: 1866
# Deleted folder: 1868
# Deleted folder: 187
# Deleted folder: 1873
# Deleted folder: 1875
# Deleted folder: 1876
# Deleted folder: 1877
# Deleted folder: 1878
# Deleted folder: 1879
# Deleted folder: 188
# Deleted folder: 1884
# Deleted folder: 1885
# Deleted folder: 1887
# Deleted folder: 189
# Deleted folder: 1890
# Deleted folder: 1891
# Deleted folder: 1892
# Deleted folder: 1893
# Deleted folder: 1894
# Deleted folder: 1898
# Deleted folder: 1899
# Deleted folder: 19
# Deleted folder: 1900
# Deleted folder: 1901
# Deleted folder: 1903
# Deleted folder: 1904
# Deleted folder: 1905
# Deleted folder: 1906
# Deleted folder: 1907
# Deleted folder: 1908
# Deleted folder: 1909
# Deleted folder: 1910
# Deleted folder: 1911
# Deleted folder: 1912
# Deleted folder: 1913
# Deleted folder: 1914
# Deleted folder: 1915
# Deleted folder: 1916
# Deleted folder: 1917
# Deleted folder: 1918
# Deleted folder: 1919
# Deleted folder: 1920
# Deleted folder: 1921
# Deleted folder: 1922
# Deleted folder: 1923
# Deleted folder: 1925
# Deleted folder: 1926
# Deleted folder: 1927
# Deleted folder: 1928
# Deleted folder: 1929
# Deleted folder: 1930
# Deleted folder: 1931
# Deleted folder: 1932
# Deleted folder: 1933
# Deleted folder: 1934
# Deleted folder: 1935
# Deleted folder: 1936
# Deleted folder: 1937
# Deleted folder: 1938
# Deleted folder: 1939
# Deleted folder: 194
# Deleted folder: 1940
# Deleted folder: 1942
# Deleted folder: 1943
# Deleted folder: 1944
# Deleted folder: 1945
# Deleted folder: 1946
# Deleted folder: 1947
# Deleted folder: 1948
# Deleted folder: 1949
# Deleted folder: 195
# Deleted folder: 1950
# Deleted folder: 1951
# Deleted folder: 1952
# Deleted folder: 1953
# Deleted folder: 1955
# Deleted folder: 1957
# Deleted folder: 1958
# Deleted folder: 1959
# Deleted folder: 1960
# Deleted folder: 1961
# Deleted folder: 1962
# Deleted folder: 1963
# Deleted folder: 1964
# Deleted folder: 1966
# Deleted folder: 1967
# Deleted folder: 1968
# Deleted folder: 1969
# Deleted folder: 1970
# Deleted folder: 1971
# Deleted folder: 1972
# Deleted folder: 1973
# Deleted folder: 1974
# Deleted folder: 1975
# Deleted folder: 1976
# Deleted folder: 1977
# Deleted folder: 1978
# Deleted folder: 1979
# Deleted folder: 1980
# Deleted folder: 1982
# Deleted folder: 1984
# Deleted folder: 1985
# Deleted folder: 1986
# Deleted folder: 1988
# Deleted folder: 1992
# Deleted folder: 1993
# Deleted folder: 1994
# Deleted folder: 1995
# Deleted folder: 1996
# Deleted folder: 1997
# Deleted folder: 1998
# Deleted folder: 1999
# Deleted folder: 20
# Deleted folder: 200
# Deleted folder: 2000
# Deleted folder: 2001
# Deleted folder: 2002
# Deleted folder: 2003
# Deleted folder: 2004
# Deleted folder: 2005
# Deleted folder: 2006
# Deleted folder: 2007
# Deleted folder: 2008
# Deleted folder: 2009
# Deleted folder: 2011
# Deleted folder: 2012
# Deleted folder: 2013
# Deleted folder: 2014
# Deleted folder: 2015
# Deleted folder: 2016
# Deleted folder: 2017
# Deleted folder: 2018
# Deleted folder: 2019
# Deleted folder: 202
# Deleted folder: 2020
# Deleted folder: 2021
# Deleted folder: 2023
# Deleted folder: 2024
# Deleted folder: 2025
# Deleted folder: 2026
# Deleted folder: 2027
# Deleted folder: 2028
# Deleted folder: 2030
# Deleted folder: 2031
# Deleted folder: 2032
# Deleted folder: 2033
# Deleted folder: 2034
# Deleted folder: 2035
# Deleted folder: 2036
# Deleted folder: 2037
# Deleted folder: 2038
# Deleted folder: 2041
# Deleted folder: 2042
# Deleted folder: 2043
# Deleted folder: 2044
# Deleted folder: 2045
# Deleted folder: 2053
# Deleted folder: 2055
# Deleted folder: 2058
# Deleted folder: 2059
# Deleted folder: 2060
# Deleted folder: 2061
# Deleted folder: 2062
# Deleted folder: 2063
# Deleted folder: 2065
# Deleted folder: 2066
# Deleted folder: 207
# Deleted folder: 2070
# Deleted folder: 2071
# Deleted folder: 2072
# Deleted folder: 2073
# Deleted folder: 2074
# Deleted folder: 2075
# Deleted folder: 2076
# Deleted folder: 2077
# Deleted folder: 2078
# Deleted folder: 2079
# Deleted folder: 208
# Deleted folder: 2081
# Deleted folder: 2083
# Deleted folder: 2089
# Deleted folder: 2090
# Deleted folder: 2091
# Deleted folder: 2094
# Deleted folder: 2095
# Deleted folder: 2096
# Deleted folder: 2097
# Deleted folder: 21
# Deleted folder: 2103
# Deleted folder: 2104
# Deleted folder: 2105
# Deleted folder: 2106
# Deleted folder: 2107
# Deleted folder: 2108
# Deleted folder: 2109
# Deleted folder: 2110
# Deleted folder: 2112
# Deleted folder: 2115
# Deleted folder: 2116
# Deleted folder: 2118
# Deleted folder: 2119
# Deleted folder: 2120
# Deleted folder: 2122
# Deleted folder: 2123
# Deleted folder: 2126
# Deleted folder: 2127
# Deleted folder: 2128
# Deleted folder: 2131
# Deleted folder: 2132
# Deleted folder: 2133
# Deleted folder: 2134
# Deleted folder: 2135
# Deleted folder: 2136
# Deleted folder: 2137
# Deleted folder: 2138
# Deleted folder: 2141
# Deleted folder: 2149
# Deleted folder: 215
# Deleted folder: 2150
# Deleted folder: 2152
# Deleted folder: 2153
# Deleted folder: 2154
# Deleted folder: 2156
# Deleted folder: 2157
# Deleted folder: 2159
# Deleted folder: 2163
# Deleted folder: 2164
# Deleted folder: 2165
# Deleted folder: 2166
# Deleted folder: 2167
# Deleted folder: 2168
# Deleted folder: 2169
# Deleted folder: 217
# Deleted folder: 2170
# Deleted folder: 2171
# Deleted folder: 2177
# Deleted folder: 2178
# Deleted folder: 2179
# Deleted folder: 218
# Deleted folder: 2180
# Deleted folder: 2181
# Deleted folder: 2182
# Deleted folder: 2183
# Deleted folder: 2185
# Deleted folder: 2188
# Deleted folder: 2189
# Deleted folder: 219
# Deleted folder: 2190
# Deleted folder: 2191
# Deleted folder: 2192
# Deleted folder: 2193
# Deleted folder: 2194
# Deleted folder: 2196
# Deleted folder: 2197
# Deleted folder: 2198
# Deleted folder: 2199
# Deleted folder: 22
# Deleted folder: 220
# Deleted folder: 2200
# Deleted folder: 2201
# Deleted folder: 2203
# Deleted folder: 2204
# Deleted folder: 2205
# Deleted folder: 2206
# Deleted folder: 2207
# Deleted folder: 2208
# Deleted folder: 221
# Deleted folder: 2211
# Deleted folder: 2212
# Deleted folder: 2216
# Deleted folder: 2218
# Deleted folder: 2219
# Deleted folder: 2220
# Deleted folder: 2221
# Deleted folder: 2224
# Deleted folder: 2226
# Deleted folder: 2227
# Deleted folder: 2228
# Deleted folder: 2229
# Deleted folder: 2231
# Deleted folder: 2234
# Deleted folder: 2235
# Deleted folder: 2236
# Deleted folder: 2237
# Deleted folder: 2238
# Deleted folder: 2240
# Deleted folder: 2241
# Deleted folder: 2242
# Deleted folder: 2243
# Deleted folder: 2244
# Deleted folder: 2245
# Deleted folder: 2246
# Deleted folder: 2248
# Deleted folder: 225
# Deleted folder: 2250
# Deleted folder: 2251
# Deleted folder: 2252
# Deleted folder: 2253
# Deleted folder: 2258
# Deleted folder: 2259
# Deleted folder: 2260
# Deleted folder: 2262
# Deleted folder: 2263
# Deleted folder: 2266
# Deleted folder: 2268
# Deleted folder: 2270
# Deleted folder: 2271
# Deleted folder: 2272
# Deleted folder: 2273
# Deleted folder: 2274
# Deleted folder: 2275
# Deleted folder: 2276
# Deleted folder: 2277
# Deleted folder: 2278
# Deleted folder: 2279
# Deleted folder: 2280
# Deleted folder: 2281
# Deleted folder: 2282
# Deleted folder: 2283
# Deleted folder: 2284
# Deleted folder: 2285
# Deleted folder: 2286
# Deleted folder: 2287
# Deleted folder: 2289
# Deleted folder: 229
# Deleted folder: 2290
# Deleted folder: 2291
# Deleted folder: 2293
# Deleted folder: 2294
# Deleted folder: 2296
# Deleted folder: 2298
# Deleted folder: 2299
# Deleted folder: 2300
# Deleted folder: 2301
# Deleted folder: 2302
# Deleted folder: 2303
# Deleted folder: 2305
# Deleted folder: 2306
# Deleted folder: 2307
# Deleted folder: 2309
# Deleted folder: 231
# Deleted folder: 2310
# Deleted folder: 2311
# Deleted folder: 2312
# Deleted folder: 2313
# Deleted folder: 2317
# Deleted folder: 2318
# Deleted folder: 2319
# Deleted folder: 2320
# Deleted folder: 2321
# Deleted folder: 2322
# Deleted folder: 2323
# Deleted folder: 2324
# Deleted folder: 2328
# Deleted folder: 2329
# Deleted folder: 2330
# Deleted folder: 2336
# Deleted folder: 2337
# Deleted folder: 2340
# Deleted folder: 2341
# Deleted folder: 2342
# Deleted folder: 2345
# Deleted folder: 2346
# Deleted folder: 2348
# Deleted folder: 2349
# Deleted folder: 235
# Deleted folder: 2350
# Deleted folder: 2351
# Deleted folder: 2353
# Deleted folder: 2354
# Deleted folder: 2355
# Deleted folder: 2356
# Deleted folder: 2357
# Deleted folder: 2358
# Deleted folder: 236
# Deleted folder: 2362
# Deleted folder: 2363
# Deleted folder: 2364
# Deleted folder: 2366
# Deleted folder: 2367
# Deleted folder: 2369
# Deleted folder: 237
# Deleted folder: 2371
# Deleted folder: 2373
# Deleted folder: 2374
# Deleted folder: 2375
# Deleted folder: 2377
# Deleted folder: 2378
# Deleted folder: 2379
# Deleted folder: 238
# Deleted folder: 2380
# Deleted folder: 2381
# Deleted folder: 2383
# Deleted folder: 2384
# Deleted folder: 2389
# Deleted folder: 239
# Deleted folder: 2391
# Deleted folder: 2392
# Deleted folder: 2395
# Deleted folder: 2396
# Deleted folder: 2398
# Deleted folder: 2399
# Deleted folder: 24
# Deleted folder: 240
# Deleted folder: 2400
# Deleted folder: 2402
# Deleted folder: 2404
# Deleted folder: 2405
# Deleted folder: 2406
# Deleted folder: 2407
# Deleted folder: 2408
# Deleted folder: 241
# Deleted folder: 2413
# Deleted folder: 2415
# Deleted folder: 2416
# Deleted folder: 2419
# Deleted folder: 242
# Deleted folder: 2421
# Deleted folder: 2422
# Deleted folder: 2423
# Deleted folder: 2424
# Deleted folder: 2425
# Deleted folder: 2426
# Deleted folder: 2427
# Deleted folder: 2428
# Deleted folder: 2432
# Deleted folder: 2436
# Deleted folder: 2438
# Deleted folder: 2440
# Deleted folder: 2443
# Deleted folder: 2444
# Deleted folder: 2446
# Deleted folder: 2448
# Deleted folder: 245
# Deleted folder: 2451
# Deleted folder: 2452
# Deleted folder: 2453
# Deleted folder: 2455
# Deleted folder: 2456
# Deleted folder: 2459
# Deleted folder: 246
# Deleted folder: 2460
# Deleted folder: 2461
# Deleted folder: 2462
# Deleted folder: 2463
# Deleted folder: 2464
# Deleted folder: 2465
# Deleted folder: 2466
# Deleted folder: 247
# Deleted folder: 2471
# Deleted folder: 2472
# Deleted folder: 2473
# Deleted folder: 2475
# Deleted folder: 2476
# Deleted folder: 2480
# Deleted folder: 2481
# Deleted folder: 2482
# Deleted folder: 2484
# Deleted folder: 2486
# Deleted folder: 2487
# Deleted folder: 2489
# Deleted folder: 249
# Deleted folder: 2490
# Deleted folder: 2492
# Deleted folder: 2495
# Deleted folder: 2497
# Deleted folder: 2499
# Deleted folder: 25
# Deleted folder: 250
# Deleted folder: 2500
# Deleted folder: 2501
# Deleted folder: 2502
# Deleted folder: 2503
# Deleted folder: 2504
# Deleted folder: 2505
# Deleted folder: 2506
# Deleted folder: 2507
# Deleted folder: 251
# Deleted folder: 2510
# Deleted folder: 2512
# Deleted folder: 252
# Deleted folder: 2524
# Deleted folder: 2526
# Deleted folder: 2527
# Deleted folder: 253
# Deleted folder: 2530
# Deleted folder: 2532
# Deleted folder: 2534
# Deleted folder: 254
# Deleted folder: 2540
# Deleted folder: 2541
# Deleted folder: 2549
# Deleted folder: 2551
# Deleted folder: 2560
# Deleted folder: 2563
# Deleted folder: 2564
# Deleted folder: 2567
# Deleted folder: 2568
# Deleted folder: 2569
# Deleted folder: 2570
# Deleted folder: 2571
# Deleted folder: 2574
# Deleted folder: 2579
# Deleted folder: 2581
# Deleted folder: 2582
# Deleted folder: 2583
# Deleted folder: 2584
# Deleted folder: 2588
# Deleted folder: 2591
# Deleted folder: 2592
# Deleted folder: 2593
# Deleted folder: 2594
# Deleted folder: 2595
# Deleted folder: 2596
# Deleted folder: 2608
# Deleted folder: 261
# Deleted folder: 2615
# Deleted folder: 2618
# Deleted folder: 262
# Deleted folder: 2622
# Deleted folder: 2623
# Deleted folder: 2624
# Deleted folder: 2625
# Deleted folder: 2626
# Deleted folder: 2627
# Deleted folder: 2628
# Deleted folder: 2629
# Deleted folder: 2630
# Deleted folder: 2631
# Deleted folder: 2632
# Deleted folder: 2633
# Deleted folder: 2638
# Deleted folder: 2639
# Deleted folder: 264
# Deleted folder: 2640
# Deleted folder: 2641
# Deleted folder: 2642
# Deleted folder: 2643
# Deleted folder: 2644
# Deleted folder: 2645
# Deleted folder: 2648
# Deleted folder: 2649
# Deleted folder: 265
# Deleted folder: 2650
# Deleted folder: 2652
# Deleted folder: 2659
# Deleted folder: 266
# Deleted folder: 2660
# Deleted folder: 2662
# Deleted folder: 2667
# Deleted folder: 2668
# Deleted folder: 2672
# Deleted folder: 2673
# Deleted folder: 2677
# Deleted folder: 2679
# Deleted folder: 268
# Deleted folder: 2680
# Deleted folder: 2684
# Deleted folder: 269
# Deleted folder: 2691
# Deleted folder: 2692
# Deleted folder: 2693
# Deleted folder: 2699
# Deleted folder: 27
# Deleted folder: 270
# Deleted folder: 2701
# Deleted folder: 2702
# Deleted folder: 2703
# Deleted folder: 271
# Deleted folder: 2710
# Deleted folder: 2715
# Deleted folder: 2716
# Deleted folder: 2717
# Deleted folder: 2718
# Deleted folder: 2719
# Deleted folder: 2720
# Deleted folder: 2721
# Deleted folder: 2723
# Deleted folder: 2724
# Deleted folder: 2725
# Deleted folder: 2726
# Deleted folder: 2727
# Deleted folder: 2728
# Deleted folder: 2729
# Deleted folder: 273
# Deleted folder: 2730
# Deleted folder: 2731
# Deleted folder: 2732
# Deleted folder: 2733
# Deleted folder: 2734
# Deleted folder: 2736
# Deleted folder: 2737
# Deleted folder: 274
# Deleted folder: 2747
# Deleted folder: 275
# Deleted folder: 2755
# Deleted folder: 2756
# Deleted folder: 2757
# Deleted folder: 2760
# Deleted folder: 2761
# Deleted folder: 2764
# Deleted folder: 2765
# Deleted folder: 2766
# Deleted folder: 2767
# Deleted folder: 2768
# Deleted folder: 2769
# Deleted folder: 2770
# Deleted folder: 2771
# Deleted folder: 2773
# Deleted folder: 2774
# Deleted folder: 2775
# Deleted folder: 2776
# Deleted folder: 2777
# Deleted folder: 2780
# Deleted folder: 2783
# Deleted folder: 2784
# Deleted folder: 2785
# Deleted folder: 2786
# Deleted folder: 2787
# Deleted folder: 2789
# Deleted folder: 2791
# Deleted folder: 2793
# Deleted folder: 2795
# Deleted folder: 2797
# Deleted folder: 2798
# Deleted folder: 2799
# Deleted folder: 28
# Deleted folder: 2800
# Deleted folder: 2801
# Deleted folder: 2802
# Deleted folder: 2803
# Deleted folder: 2805
# Deleted folder: 2806
# Deleted folder: 2807
# Deleted folder: 2808
# Deleted folder: 2809
# Deleted folder: 2810
# Deleted folder: 2811
# Deleted folder: 2813
# Deleted folder: 2814
# Deleted folder: 2816
# Deleted folder: 2817
# Deleted folder: 2818
# Deleted folder: 2821
# Deleted folder: 2824
# Deleted folder: 2826
# Deleted folder: 2827
# Deleted folder: 2828
# Deleted folder: 2829
# Deleted folder: 283
# Deleted folder: 2830
# Deleted folder: 2831
# Deleted folder: 2832
# Deleted folder: 2833
# Deleted folder: 2834
# Deleted folder: 2835
# Deleted folder: 2836
# Deleted folder: 2837
# Deleted folder: 2838
# Deleted folder: 2839
# Deleted folder: 284
# Deleted folder: 2840
# Deleted folder: 2842
# Deleted folder: 2844
# Deleted folder: 2845
# Deleted folder: 2846
# Deleted folder: 2847
# Deleted folder: 2851
# Deleted folder: 2852
# Deleted folder: 2861
# Deleted folder: 2862
# Deleted folder: 2863
# Deleted folder: 2864
# Deleted folder: 2865
# Deleted folder: 2866
# Deleted folder: 2868
# Deleted folder: 2869
# Deleted folder: 2872
# Deleted folder: 2874
# Deleted folder: 2875
# Deleted folder: 2877
# Deleted folder: 2879
# Deleted folder: 288
# Deleted folder: 2881
# Deleted folder: 2888
# Deleted folder: 2890
# Deleted folder: 2892
# Deleted folder: 2895
# Deleted folder: 2896
# Deleted folder: 2897
# Deleted folder: 290
# Deleted folder: 2900
# Deleted folder: 2901
# Deleted folder: 2905
# Deleted folder: 2908
# Deleted folder: 2909
# Deleted folder: 2910
# Deleted folder: 2912
# Deleted folder: 2916
# Deleted folder: 2917
# Deleted folder: 2920
# Deleted folder: 2921
# Deleted folder: 2923
# Deleted folder: 2924
# Deleted folder: 2925
# Deleted folder: 2926
# Deleted folder: 2927
# Deleted folder: 2928
# Deleted folder: 2929
# Deleted folder: 2930
# Deleted folder: 2931
# Deleted folder: 2932
# Deleted folder: 2934
# Deleted folder: 2936
# Deleted folder: 2939
# Deleted folder: 2940
# Deleted folder: 2941
# Deleted folder: 2942
# Deleted folder: 2943
# Deleted folder: 2945
# Deleted folder: 2946
# Deleted folder: 2947
# Deleted folder: 2948
# Deleted folder: 2954
# Deleted folder: 2956
# Deleted folder: 2957
# Deleted folder: 2958
# Deleted folder: 2959
# Deleted folder: 296
# Deleted folder: 2960
# Deleted folder: 2961
# Deleted folder: 2962
# Deleted folder: 2963
# Deleted folder: 2964
# Deleted folder: 2965
# Deleted folder: 2966
# Deleted folder: 2967
# Deleted folder: 2968
# Deleted folder: 2969
# Deleted folder: 297
# Deleted folder: 2971
# Deleted folder: 2972
# Deleted folder: 2973
# Deleted folder: 2974
# Deleted folder: 2976
# Deleted folder: 2977
# Deleted folder: 2979
# Deleted folder: 298
# Deleted folder: 2984
# Deleted folder: 2985
# Deleted folder: 2986
# Deleted folder: 2987
# Deleted folder: 2988
# Deleted folder: 2989
# Deleted folder: 299
# Deleted folder: 2990
# Deleted folder: 2991
# Deleted folder: 2993
# Deleted folder: 2995
# Deleted folder: 2997
# Deleted folder: 2998
# Deleted folder: 2999
# Deleted folder: 30
# Deleted folder: 3000
# Deleted folder: 3002
# Deleted folder: 3003
# Deleted folder: 3004
# Deleted folder: 3005
# Deleted folder: 3008
# Deleted folder: 3010
# Deleted folder: 3011
# Deleted folder: 3013
# Deleted folder: 3017
# Deleted folder: 3018
# Deleted folder: 3019
# Deleted folder: 302
# Deleted folder: 3020
# Deleted folder: 3023
# Deleted folder: 3024
# Deleted folder: 3025
# Deleted folder: 3029
# Deleted folder: 303
# Deleted folder: 3031
# Deleted folder: 3032
# Deleted folder: 3033
# Deleted folder: 3034
# Deleted folder: 3035
# Deleted folder: 3036
# Deleted folder: 3037
# Deleted folder: 3040
# Deleted folder: 3042
# Deleted folder: 3043
# Deleted folder: 3046
# Deleted folder: 3047
# Deleted folder: 3050
# Deleted folder: 3055
# Deleted folder: 3056
# Deleted folder: 3058
# Deleted folder: 3059
# Deleted folder: 3060
# Deleted folder: 3062
# Deleted folder: 3063
# Deleted folder: 3066
# Deleted folder: 3068
# Deleted folder: 3069
# Deleted folder: 3070
# Deleted folder: 3071
# Deleted folder: 3072
# Deleted folder: 3074
# Deleted folder: 3076
# Deleted folder: 3077
# Deleted folder: 3078
# Deleted folder: 3079
# Deleted folder: 3080
# Deleted folder: 3081
# Deleted folder: 3082
# Deleted folder: 3087
# Deleted folder: 309
# Deleted folder: 3091
# Deleted folder: 3092
# Deleted folder: 3093
# Deleted folder: 3094
# Deleted folder: 3095
# Deleted folder: 3097
# Deleted folder: 3098
# Deleted folder: 31
# Deleted folder: 310
# Deleted folder: 3106
# Deleted folder: 3107
# Deleted folder: 3108
# Deleted folder: 3110
# Deleted folder: 3111
# Deleted folder: 3112
# Deleted folder: 3113
# Deleted folder: 3114
# Deleted folder: 3115
# Deleted folder: 3116
# Deleted folder: 3118
# Deleted folder: 3119
# Deleted folder: 3120
# Deleted folder: 3123
# Deleted folder: 3127
# Deleted folder: 3129
# Deleted folder: 313
# Deleted folder: 3130
# Deleted folder: 3131
# Deleted folder: 3132
# Deleted folder: 3133
# Deleted folder: 3134
# Deleted folder: 3135
# Deleted folder: 3137
# Deleted folder: 3139
# Deleted folder: 3140
# Deleted folder: 3141
# Deleted folder: 3143
# Deleted folder: 3145
# Deleted folder: 3146
# Deleted folder: 3147
# Deleted folder: 3148
# Deleted folder: 3149
# Deleted folder: 3151
# Deleted folder: 3153
# Deleted folder: 3154
# Deleted folder: 3155
# Deleted folder: 3157
# Deleted folder: 3158
# Deleted folder: 3159
# Deleted folder: 316
# Deleted folder: 3160
# Deleted folder: 3161
# Deleted folder: 3162
# Deleted folder: 3163
# Deleted folder: 3164
# Deleted folder: 3165
# Deleted folder: 3166
# Deleted folder: 3170
# Deleted folder: 3172
# Deleted folder: 3173
# Deleted folder: 3174
# Deleted folder: 318
# Deleted folder: 3183
# Deleted folder: 3187
# Deleted folder: 3188
# Deleted folder: 319
# Deleted folder: 3190
# Deleted folder: 3193
# Deleted folder: 3194
# Deleted folder: 3196
# Deleted folder: 3197
# Deleted folder: 3198
# Deleted folder: 3199
# Deleted folder: 320
# Deleted folder: 3200
# Deleted folder: 3201
# Deleted folder: 3202
# Deleted folder: 3203
# Deleted folder: 3205
# Deleted folder: 3207
# Deleted folder: 3210
# Deleted folder: 3211
# Deleted folder: 3214
# Deleted folder: 3215
# Deleted folder: 3217
# Deleted folder: 3218
# Deleted folder: 3219
# Deleted folder: 3220
# Deleted folder: 3221
# Deleted folder: 3222
# Deleted folder: 3223
# Deleted folder: 3225
# Deleted folder: 3226
# Deleted folder: 3227
# Deleted folder: 3228
# Deleted folder: 3229
# Deleted folder: 3230
# Deleted folder: 3232
# Deleted folder: 3233
# Deleted folder: 3234
# Deleted folder: 3235
# Deleted folder: 3236
# Deleted folder: 3237
# Deleted folder: 3238
# Deleted folder: 3240
# Deleted folder: 3241
# Deleted folder: 3242
# Deleted folder: 3243
# Deleted folder: 3244
# Deleted folder: 3246
# Deleted folder: 3248
# Deleted folder: 3249
# Deleted folder: 3250
# Deleted folder: 3251
# Deleted folder: 3252
# Deleted folder: 3257
# Deleted folder: 3258
# Deleted folder: 3259
# Deleted folder: 326
# Deleted folder: 3260
# Deleted folder: 3263
# Deleted folder: 3264
# Deleted folder: 3267
# Deleted folder: 3268
# Deleted folder: 3269
# Deleted folder: 327
# Deleted folder: 3270
# Deleted folder: 3275
# Deleted folder: 3276
# Deleted folder: 3280
# Deleted folder: 3282
# Deleted folder: 3284
# Deleted folder: 3285
# Deleted folder: 3286
# Deleted folder: 3288
# Deleted folder: 3289
# Deleted folder: 329
# Deleted folder: 3290
# Deleted folder: 3293
# Deleted folder: 3296
# Deleted folder: 3299
# Deleted folder: 330
# Deleted folder: 3303
# Deleted folder: 3304
# Deleted folder: 3305
# Deleted folder: 3306
# Deleted folder: 3308
# Deleted folder: 3309
# Deleted folder: 331
# Deleted folder: 3310
# Deleted folder: 3312
# Deleted folder: 3313
# Deleted folder: 3314
# Deleted folder: 3315
# Deleted folder: 3316
# Deleted folder: 3317
# Deleted folder: 3318
# Deleted folder: 3319
# Deleted folder: 332
# Deleted folder: 3320
# Deleted folder: 3321
# Deleted folder: 3323
# Deleted folder: 3325
# Deleted folder: 3326
# Deleted folder: 3327
# Deleted folder: 3329
# Deleted folder: 333
# Deleted folder: 3330
# Deleted folder: 3332
# Deleted folder: 3334
# Deleted folder: 3335
# Deleted folder: 3336
# Deleted folder: 3338
# Deleted folder: 3340
# Deleted folder: 3341
# Deleted folder: 3342
# Deleted folder: 3343
# Deleted folder: 3344
# Deleted folder: 3345
# Deleted folder: 3346
# Deleted folder: 3347
# Deleted folder: 3349
# Deleted folder: 335
# Deleted folder: 3350
# Deleted folder: 3354
# Deleted folder: 3355
# Deleted folder: 3356
# Deleted folder: 3358
# Deleted folder: 3359
# Deleted folder: 3360
# Deleted folder: 3363
# Deleted folder: 3364
# Deleted folder: 3365
# Deleted folder: 3366
# Deleted folder: 3369
# Deleted folder: 337
# Deleted folder: 3370
# Deleted folder: 3371
# Deleted folder: 3375
# Deleted folder: 3376
# Deleted folder: 3377
# Deleted folder: 338
# Deleted folder: 3384
# Deleted folder: 3385
# Deleted folder: 3388
# Deleted folder: 3389
# Deleted folder: 339
# Deleted folder: 3390
# Deleted folder: 3391
# Deleted folder: 3392
# Deleted folder: 3393
# Deleted folder: 3394
# Deleted folder: 3395
# Deleted folder: 3396
# Deleted folder: 3397
# Deleted folder: 3398
# Deleted folder: 34
# Deleted folder: 340
# Deleted folder: 3400
# Deleted folder: 3401
# Deleted folder: 3402
# Deleted folder: 3404
# Deleted folder: 3408
# Deleted folder: 3409
# Deleted folder: 341
# Deleted folder: 3410
# Deleted folder: 3412
# Deleted folder: 3413
# Deleted folder: 3415
# Deleted folder: 3418
# Deleted folder: 342
# Deleted folder: 3422
# Deleted folder: 3423
# Deleted folder: 3424
# Deleted folder: 3426
# Deleted folder: 3427
# Deleted folder: 3428
# Deleted folder: 3429
# Deleted folder: 343
# Deleted folder: 3430
# Deleted folder: 3431
# Deleted folder: 3432
# Deleted folder: 3433
# Deleted folder: 3437
# Deleted folder: 3438
# Deleted folder: 3439
# Deleted folder: 3440
# Deleted folder: 3441
# Deleted folder: 3442
# Deleted folder: 3449
# Deleted folder: 3453
# Deleted folder: 3455
# Deleted folder: 3457
# Deleted folder: 3459
# Deleted folder: 3460
# Deleted folder: 3461
# Deleted folder: 3462
# Deleted folder: 3463
# Deleted folder: 3464
# Deleted folder: 3465
# Deleted folder: 3466
# Deleted folder: 3468
# Deleted folder: 3469
# Deleted folder: 3472
# Deleted folder: 3473
# Deleted folder: 3476
# Deleted folder: 3477
# Deleted folder: 3478
# Deleted folder: 3479
# Deleted folder: 3482
# Deleted folder: 3484
# Deleted folder: 3485
# Deleted folder: 3486
# Deleted folder: 3487
# Deleted folder: 3488
# Deleted folder: 3490
# Deleted folder: 3491
# Deleted folder: 3494
# Deleted folder: 3495
# Deleted folder: 3496
# Deleted folder: 3498
# Deleted folder: 3499
# Deleted folder: 35
# Deleted folder: 3500
# Deleted folder: 3501
# Deleted folder: 3502
# Deleted folder: 3503
# Deleted folder: 3505
# Deleted folder: 3506
# Deleted folder: 3507
# Deleted folder: 3508
# Deleted folder: 3509
# Deleted folder: 3510
# Deleted folder: 3512
# Deleted folder: 3513
# Deleted folder: 3514
# Deleted folder: 3515
# Deleted folder: 3519
# Deleted folder: 3520
# Deleted folder: 3521
# Deleted folder: 3524
# Deleted folder: 3527
# Deleted folder: 3528
# Deleted folder: 3530
# Deleted folder: 3531
# Deleted folder: 3534
# Deleted folder: 3535
# Deleted folder: 3536
# Deleted folder: 3537
# Deleted folder: 3538
# Deleted folder: 3539
# Deleted folder: 354
# Deleted folder: 3540
# Deleted folder: 3541
# Deleted folder: 3542
# Deleted folder: 3543
# Deleted folder: 3544
# Deleted folder: 3545
# Deleted folder: 3546
# Deleted folder: 3548
# Deleted folder: 3549
# Deleted folder: 355
# Deleted folder: 3550
# Deleted folder: 3551
# Deleted folder: 3552
# Deleted folder: 3553
# Deleted folder: 3556
# Deleted folder: 3558
# Deleted folder: 356
# Deleted folder: 3561
# Deleted folder: 3562
# Deleted folder: 3563
# Deleted folder: 3565
# Deleted folder: 3568
# Deleted folder: 3569
# Deleted folder: 357
# Deleted folder: 3570
# Deleted folder: 3571
# Deleted folder: 3572
# Deleted folder: 3573
# Deleted folder: 3574
# Deleted folder: 3576
# Deleted folder: 3578
# Deleted folder: 3579
# Deleted folder: 3581
# Deleted folder: 3582
# Deleted folder: 3584
# Deleted folder: 3585
# Deleted folder: 3586
# Deleted folder: 3587
# Deleted folder: 3589
# Deleted folder: 359
# Deleted folder: 3590
# Deleted folder: 3592
# Deleted folder: 3593
# Deleted folder: 3594
# Deleted folder: 3595
# Deleted folder: 3596
# Deleted folder: 3597
# Deleted folder: 3598
# Deleted folder: 36
# Deleted folder: 3601
# Deleted folder: 3602
# Deleted folder: 3605
# Deleted folder: 3608
# Deleted folder: 3609
# Deleted folder: 361
# Deleted folder: 3616
# Deleted folder: 3617
# Deleted folder: 3618
# Deleted folder: 3619
# Deleted folder: 362
# Deleted folder: 3620
# Deleted folder: 3621
# Deleted folder: 3622
# Deleted folder: 3624
# Deleted folder: 3625
# Deleted folder: 3626
# Deleted folder: 3627
# Deleted folder: 363
# Deleted folder: 3634
# Deleted folder: 3637
# Deleted folder: 3639
# Deleted folder: 3640
# Deleted folder: 3641
# Deleted folder: 3649
# Deleted folder: 365
# Deleted folder: 3655
# Deleted folder: 3657
# Deleted folder: 366
# Deleted folder: 3662
# Deleted folder: 3663
# Deleted folder: 3665
# Deleted folder: 3667
# Deleted folder: 3668
# Deleted folder: 367
# Deleted folder: 3670
# Deleted folder: 3671
# Deleted folder: 3672
# Deleted folder: 3673
# Deleted folder: 3677
# Deleted folder: 3678
# Deleted folder: 3679
# Deleted folder: 3680
# Deleted folder: 3681
# Deleted folder: 3682
# Deleted folder: 3689
# Deleted folder: 369
# Deleted folder: 3690
# Deleted folder: 3691
# Deleted folder: 3692
# Deleted folder: 3693
# Deleted folder: 3694
# Deleted folder: 3695
# Deleted folder: 3697
# Deleted folder: 3699
# Deleted folder: 370
# Deleted folder: 3700
# Deleted folder: 3701
# Deleted folder: 3703
# Deleted folder: 3704
# Deleted folder: 3705
# Deleted folder: 3706
# Deleted folder: 3708
# Deleted folder: 3709
# Deleted folder: 3710
# Deleted folder: 3711
# Deleted folder: 3713
# Deleted folder: 3714
# Deleted folder: 3716
# Deleted folder: 3717
# Deleted folder: 3718
# Deleted folder: 3719
# Deleted folder: 3720
# Deleted folder: 3721
# Deleted folder: 3723
# Deleted folder: 3725
# Deleted folder: 3726
# Deleted folder: 3728
# Deleted folder: 3729
# Deleted folder: 373
# Deleted folder: 3730
# Deleted folder: 3731
# Deleted folder: 3734
# Deleted folder: 3735
# Deleted folder: 3736
# Deleted folder: 3738
# Deleted folder: 3739
# Deleted folder: 3740
# Deleted folder: 3742
# Deleted folder: 3746
# Deleted folder: 3747
# Deleted folder: 3748
# Deleted folder: 3749
# Deleted folder: 375
# Deleted folder: 3750
# Deleted folder: 3751
# Deleted folder: 3752
# Deleted folder: 3753
# Deleted folder: 3754
# Deleted folder: 3755
# Deleted folder: 3757
# Deleted folder: 3758
# Deleted folder: 376
# Deleted folder: 3760
# Deleted folder: 3762
# Deleted folder: 3763
# Deleted folder: 3765
# Deleted folder: 3766
# Deleted folder: 377
# Deleted folder: 3770
# Deleted folder: 3772
# Deleted folder: 3773
# Deleted folder: 3774
# Deleted folder: 3776
# Deleted folder: 3777
# Deleted folder: 3778
# Deleted folder: 378
# Deleted folder: 3781
# Deleted folder: 3783
# Deleted folder: 3784
# Deleted folder: 3785
# Deleted folder: 3786
# Deleted folder: 3787
# Deleted folder: 3788
# Deleted folder: 379
# Deleted folder: 3791
# Deleted folder: 3792
# Deleted folder: 3793
# Deleted folder: 3794
# Deleted folder: 3795
# Deleted folder: 3796
# Deleted folder: 3797
# Deleted folder: 3798
# Deleted folder: 3799
# Deleted folder: 38
# Deleted folder: 380
# Deleted folder: 3801
# Deleted folder: 3802
# Deleted folder: 3803
# Deleted folder: 3804
# Deleted folder: 3805
# Deleted folder: 3806
# Deleted folder: 3807
# Deleted folder: 3808
# Deleted folder: 3809
# Deleted folder: 3810
# Deleted folder: 3812
# Deleted folder: 3817
# Deleted folder: 382
# Deleted folder: 3820
# Deleted folder: 3821
# Deleted folder: 3822
# Deleted folder: 3823
# Deleted folder: 3824
# Deleted folder: 3825
# Deleted folder: 3826
# Deleted folder: 3828
# Deleted folder: 383
# Deleted folder: 3830
# Deleted folder: 3832
# Deleted folder: 3833
# Deleted folder: 3834
# Deleted folder: 3835
# Deleted folder: 3838
# Deleted folder: 3839
# Deleted folder: 3841
# Deleted folder: 3842
# Deleted folder: 3843
# Deleted folder: 3844
# Deleted folder: 3845
# Deleted folder: 3846
# Deleted folder: 3847
# Deleted folder: 3848
# Deleted folder: 3849
# Deleted folder: 385
# Deleted folder: 3851
# Deleted folder: 3852
# Deleted folder: 3853
# Deleted folder: 386
# Deleted folder: 3863
# Deleted folder: 3864
# Deleted folder: 3865
# Deleted folder: 3866
# Deleted folder: 3868
# Deleted folder: 3869
# Deleted folder: 3870
# Deleted folder: 3871
# Deleted folder: 3873
# Deleted folder: 3874
# Deleted folder: 3875
# Deleted folder: 3877
# Deleted folder: 3878
# Deleted folder: 3879
# Deleted folder: 388
# Deleted folder: 3880
# Deleted folder: 3882
# Deleted folder: 3883
# Deleted folder: 3884
# Deleted folder: 3885
# Deleted folder: 3887
# Deleted folder: 3888
# Deleted folder: 3889
# Deleted folder: 389
# Deleted folder: 3890
# Deleted folder: 3891
# Deleted folder: 3892
# Deleted folder: 3893
# Deleted folder: 3895
# Deleted folder: 3896
# Deleted folder: 390
# Deleted folder: 3900
# Deleted folder: 3901
# Deleted folder: 3902
# Deleted folder: 3906
# Deleted folder: 3908
# Deleted folder: 3910
# Deleted folder: 3911
# Deleted folder: 3912
# Deleted folder: 3913
# Deleted folder: 3914
# Deleted folder: 3915
# Deleted folder: 3916
# Deleted folder: 3917
# Deleted folder: 3919
# Deleted folder: 3922
# Deleted folder: 3923
# Deleted folder: 3924
# Deleted folder: 3925
# Deleted folder: 3930
# Deleted folder: 3934
# Deleted folder: 3935
# Deleted folder: 3936
# Deleted folder: 3937
# Deleted folder: 3938
# Deleted folder: 3939
# Deleted folder: 394
# Deleted folder: 3940
# Deleted folder: 3942
# Deleted folder: 3943
# Deleted folder: 3946
# Deleted folder: 3949
# Deleted folder: 3950
# Deleted folder: 3951
# Deleted folder: 3952
# Deleted folder: 3954
# Deleted folder: 3955
# Deleted folder: 3956
# Deleted folder: 3958
# Deleted folder: 3959
# Deleted folder: 3960
# Deleted folder: 3961
# Deleted folder: 3962
# Deleted folder: 3964
# Deleted folder: 3966
# Deleted folder: 3968
# Deleted folder: 3969
# Deleted folder: 397
# Deleted folder: 3970
# Deleted folder: 3971
# Deleted folder: 3972
# Deleted folder: 3974
# Deleted folder: 3976
# Deleted folder: 3978
# Deleted folder: 3979
# Deleted folder: 398
# Deleted folder: 3980
# Deleted folder: 3981
# Deleted folder: 3982
# Deleted folder: 3984
# Deleted folder: 3986
# Deleted folder: 3991
# Deleted folder: 3992
# Deleted folder: 3993
# Deleted folder: 3994
# Deleted folder: 3996
# Deleted folder: 3997
# Deleted folder: 3998
# Deleted folder: 3999
# Deleted folder: 40
# Deleted folder: 4000
# Deleted folder: 4001
# Deleted folder: 4004
# Deleted folder: 4005
# Deleted folder: 4006
# Deleted folder: 4008
# Deleted folder: 4009
# Deleted folder: 401
# Deleted folder: 4010
# Deleted folder: 4011
# Deleted folder: 4012
# Deleted folder: 4013
# Deleted folder: 4014
# Deleted folder: 4015
# Deleted folder: 4016
# Deleted folder: 4018
# Deleted folder: 4019
# Deleted folder: 402
# Deleted folder: 4020
# Deleted folder: 4021
# Deleted folder: 4022
# Deleted folder: 4023
# Deleted folder: 4025
# Deleted folder: 4026
# Deleted folder: 4027
# Deleted folder: 4028
# Deleted folder: 4029
# Deleted folder: 403
# Deleted folder: 4033
# Deleted folder: 4034
# Deleted folder: 4036
# Deleted folder: 4038
# Deleted folder: 4039
# Deleted folder: 404
# Deleted folder: 4040
# Deleted folder: 4041
# Deleted folder: 4043
# Deleted folder: 4044
# Deleted folder: 4045
# Deleted folder: 4046
# Deleted folder: 4047
# Deleted folder: 4048
# Deleted folder: 405
# Deleted folder: 4050
# Deleted folder: 4051
# Deleted folder: 4052
# Deleted folder: 4054
# Deleted folder: 4055
# Deleted folder: 4056
# Deleted folder: 4057
# Deleted folder: 4059
# Deleted folder: 406
# Deleted folder: 4060
# Deleted folder: 4061
# Deleted folder: 4062
# Deleted folder: 4063
# Deleted folder: 4064
# Deleted folder: 4067
# Deleted folder: 4068
# Deleted folder: 4069
# Deleted folder: 407
# Deleted folder: 4070
# Deleted folder: 4071
# Deleted folder: 4072
# Deleted folder: 4073
# Deleted folder: 4074
# Deleted folder: 4075
# Deleted folder: 4076
# Deleted folder: 4077
# Deleted folder: 4078
# Deleted folder: 4079
# Deleted folder: 4082
# Deleted folder: 4084
# Deleted folder: 4085
# Deleted folder: 4086
# Deleted folder: 4087
# Deleted folder: 4088
# Deleted folder: 409
# Deleted folder: 4091
# Deleted folder: 4092
# Deleted folder: 4093
# Deleted folder: 4094
# Deleted folder: 4095
# Deleted folder: 4096
# Deleted folder: 4097
# Deleted folder: 4099
# Deleted folder: 41
# Deleted folder: 4100
# Deleted folder: 4101
# Deleted folder: 4102
# Deleted folder: 4103
# Deleted folder: 4104
# Deleted folder: 4105
# Deleted folder: 4106
# Deleted folder: 4107
# Deleted folder: 4108
# Deleted folder: 4109
# Deleted folder: 4110
# Deleted folder: 4112
# Deleted folder: 4113
# Deleted folder: 4114
# Deleted folder: 4115
# Deleted folder: 4117
# Deleted folder: 4118
# Deleted folder: 412
# Deleted folder: 4121
# Deleted folder: 4122
# Deleted folder: 4123
# Deleted folder: 4125
# Deleted folder: 4126
# Deleted folder: 4128
# Deleted folder: 4129
# Deleted folder: 413
# Deleted folder: 4130
# Deleted folder: 4131
# Deleted folder: 4132
# Deleted folder: 4133
# Deleted folder: 4135
# Deleted folder: 4136
# Deleted folder: 4137
# Deleted folder: 4138
# Deleted folder: 4139
# Deleted folder: 414
# Deleted folder: 4140
# Deleted folder: 4141
# Deleted folder: 4143
# Deleted folder: 4145
# Deleted folder: 4146
# Deleted folder: 4147
# Deleted folder: 4148
# Deleted folder: 4149
# Deleted folder: 4150
# Deleted folder: 4151
# Deleted folder: 4152
# Deleted folder: 4154
# Deleted folder: 4155
# Deleted folder: 4156
# Deleted folder: 4157
# Deleted folder: 4158
# Deleted folder: 416
# Deleted folder: 4160
# Deleted folder: 4161
# Deleted folder: 4162
# Deleted folder: 4163
# Deleted folder: 4164
# Deleted folder: 4166
# Deleted folder: 4167
# Deleted folder: 4168
# Deleted folder: 4169
# Deleted folder: 417
# Deleted folder: 4170
# Deleted folder: 4171
# Deleted folder: 4172
# Deleted folder: 4173
# Deleted folder: 4174
# Deleted folder: 4175
# Deleted folder: 4176
# Deleted folder: 4177
# Deleted folder: 4178
# Deleted folder: 4179
# Deleted folder: 418
# Deleted folder: 4180
# Deleted folder: 4181
# Deleted folder: 4182
# Deleted folder: 4183
# Deleted folder: 4185
# Deleted folder: 4186
# Deleted folder: 4187
# Deleted folder: 4188
# Deleted folder: 4189
# Deleted folder: 419
# Deleted folder: 4191
# Deleted folder: 4192
# Deleted folder: 4194
# Deleted folder: 4196
# Deleted folder: 4199
# Deleted folder: 4201
# Deleted folder: 4202
# Deleted folder: 4204
# Deleted folder: 4205
# Deleted folder: 4206
# Deleted folder: 4207
# Deleted folder: 421
# Deleted folder: 4214
# Deleted folder: 4215
# Deleted folder: 4216
# Deleted folder: 4217
# Deleted folder: 4219
# Deleted folder: 4220
# Deleted folder: 4224
# Deleted folder: 4226
# Deleted folder: 4227
# Deleted folder: 4229
# Deleted folder: 4231
# Deleted folder: 4232
# Deleted folder: 4233
# Deleted folder: 424
# ...
# Deleted folder: 4702
# Deleted folder: 4703
# Deleted folder: 4704
# Deleted folder: 4705
# Deleted folder: 4706
# Deleted folder: 4707
# Deleted folder: 4708
# Deleted folder: 471
# Deleted folder: 4710
# Deleted folder: 4711
# Deleted folder: 4712
# Deleted folder: 4713
# Deleted folder: 4715
# Deleted folder: 4716
# Deleted folder: 4717
# Deleted folder: 4718
# Deleted folder: 4719
# Deleted folder: 4720
# Deleted folder: 4721
# Deleted folder: 4722
# Deleted folder: 4723
# Deleted folder: 4724
# Deleted folder: 4725
# Deleted folder: 4727
# Deleted folder: 4728
# Deleted folder: 4729
# Deleted folder: 4731
# Deleted folder: 4733
# Deleted folder: 4734
# Deleted folder: 4736
# Deleted folder: 4737
# Deleted folder: 4740
# Deleted folder: 4741
# Deleted folder: 4742
# Deleted folder: 4743
# Deleted folder: 4744
# Deleted folder: 4750
# Deleted folder: 4751
# Deleted folder: 4752
# Deleted folder: 4753
# Deleted folder: 4754
# Deleted folder: 4755
# Deleted folder: 4756
# Deleted folder: 4758
# Deleted folder: 4759
# Deleted folder: 4760
# Deleted folder: 4761
# Deleted folder: 4762
# Deleted folder: 4765
# Deleted folder: 4766
# Deleted folder: 4767
# Deleted folder: 4768
# Deleted folder: 4769
# Deleted folder: 4771
# Deleted folder: 4773
# Deleted folder: 4774
# Deleted folder: 4776
# Deleted folder: 4778
# Deleted folder: 4781
# Deleted folder: 4782
# Deleted folder: 4783
# Deleted folder: 4784
# Deleted folder: 4785
# Deleted folder: 4786
# Deleted folder: 4787
# Deleted folder: 4790
# Deleted folder: 4797
# Deleted folder: 4798
# Deleted folder: 48
# Deleted folder: 4800
# Deleted folder: 4801
# Deleted folder: 4802
# Deleted folder: 4803
# Deleted folder: 4805
# Deleted folder: 4806
# Deleted folder: 4807
# Deleted folder: 4808
# Deleted folder: 4811
# Deleted folder: 4812
# Deleted folder: 4813
# Deleted folder: 4815
# Deleted folder: 4816
# Deleted folder: 4818
# Deleted folder: 4824
# Deleted folder: 4825
# Deleted folder: 4826
# Deleted folder: 4827
# Deleted folder: 4828
# Deleted folder: 4829
# Deleted folder: 4831
# Deleted folder: 4832
# Deleted folder: 4833
# Deleted folder: 4834
# Deleted folder: 4836
# Deleted folder: 4837
# Deleted folder: 4838
# Deleted folder: 4839
# Deleted folder: 484
# Deleted folder: 4840
# Deleted folder: 4845
# Deleted folder: 4846
# Deleted folder: 4849
# Deleted folder: 4853
# Deleted folder: 4854
# Deleted folder: 4856
# Deleted folder: 4857
# Deleted folder: 4858
# Deleted folder: 4859
# Deleted folder: 4860
# Deleted folder: 4862
# Deleted folder: 4864
# Deleted folder: 4865
# Deleted folder: 4866
# Deleted folder: 4867
# Deleted folder: 4868
# Deleted folder: 4869
# Deleted folder: 4870
# Deleted folder: 4871
# Deleted folder: 4872
# Deleted folder: 4873
# Deleted folder: 4874
# Deleted folder: 4879
# Deleted folder: 4880
# Deleted folder: 4881
# Deleted folder: 4882
# Deleted folder: 4883
# Deleted folder: 4884
# Deleted folder: 4885
# Deleted folder: 4892
# Deleted folder: 4894
# Deleted folder: 4895
# Deleted folder: 4896
# Deleted folder: 4898
# Deleted folder: 4899
# Deleted folder: 49
# Deleted folder: 490
# Deleted folder: 4900
# Deleted folder: 4904
# Deleted folder: 4906
# Deleted folder: 4907
# Deleted folder: 4908
# Deleted folder: 4909
# Deleted folder: 491
# Deleted folder: 4910
# Deleted folder: 4911
# Deleted folder: 4913
# Deleted folder: 4914
# Deleted folder: 4915
# Deleted folder: 4916
# Deleted folder: 4917
# Deleted folder: 4918
# Deleted folder: 492
# Deleted folder: 4921
# Deleted folder: 4922
# Deleted folder: 4925
# Deleted folder: 4926
# Deleted folder: 4927
# Deleted folder: 4928
# Deleted folder: 4929
# Deleted folder: 4930
# Deleted folder: 4931
# Deleted folder: 4932
# Deleted folder: 4933
# Deleted folder: 4934
# Deleted folder: 4935
# Deleted folder: 4936
# Deleted folder: 4937
# Deleted folder: 4938
# Deleted folder: 4940
# Deleted folder: 4941
# Deleted folder: 4942
# Deleted folder: 4943
# Deleted folder: 4945
# Deleted folder: 4946
# Deleted folder: 4947
# Deleted folder: 4948
# Deleted folder: 4949
# Deleted folder: 4950
# Deleted folder: 4953
# Deleted folder: 4956
# Deleted folder: 4957
# Deleted folder: 4958
# Deleted folder: 4964
# Deleted folder: 4968
# Deleted folder: 4971
# Deleted folder: 4975
# Deleted folder: 4976
# Deleted folder: 4977
# Deleted folder: 4978
# Deleted folder: 4981
# Deleted folder: 4982
# Deleted folder: 4983
# Deleted folder: 4986
# Deleted folder: 4988
# Deleted folder: 499
# Deleted folder: 4992
# Deleted folder: 4993
# Deleted folder: 4995
# Deleted folder: 4996
# Deleted folder: 4997
# Deleted folder: 5
# Deleted folder: 50
# Deleted folder: 500
# Deleted folder: 5003
# Deleted folder: 5004
# Deleted folder: 5005
# Deleted folder: 5006
# Deleted folder: 5007
# Deleted folder: 5008
# Deleted folder: 501
# Deleted folder: 5011
# Deleted folder: 5012
# Deleted folder: 5014
# Deleted folder: 5015
# Deleted folder: 5016
# Deleted folder: 5020
# Deleted folder: 5023
# Deleted folder: 5024
# Deleted folder: 5025
# Deleted folder: 5027
# Deleted folder: 5028
# Deleted folder: 5029
# Deleted folder: 503
# Deleted folder: 5033
# Deleted folder: 5039
# Deleted folder: 5040
# Deleted folder: 5042
# Deleted folder: 5043
# Deleted folder: 5045
# Deleted folder: 5046
# Deleted folder: 5047
# Deleted folder: 5048
# Deleted folder: 5049
# Deleted folder: 5051
# Deleted folder: 5053
# Deleted folder: 5054
# Deleted folder: 5055
# Deleted folder: 5056
# Deleted folder: 5059
# Deleted folder: 5063
# Deleted folder: 5064
# Deleted folder: 5066
# Deleted folder: 5067
# Deleted folder: 5068
# Deleted folder: 5069
# Deleted folder: 5070
# Deleted folder: 5071
# Deleted folder: 5072
# Deleted folder: 5073
# Deleted folder: 5074
# Deleted folder: 5075
# Deleted folder: 5076
# Deleted folder: 5078
# Deleted folder: 508
# Deleted folder: 5080
# Deleted folder: 5083
# Deleted folder: 5085
# Deleted folder: 5086
# Deleted folder: 5087
# Deleted folder: 5091
# Deleted folder: 5092
# Deleted folder: 5094
# Deleted folder: 5096
# Deleted folder: 5098
# Deleted folder: 51
# Deleted folder: 5102
# Deleted folder: 5103
# Deleted folder: 5106
# Deleted folder: 5107
# Deleted folder: 5109
# Deleted folder: 5110
# Deleted folder: 5111
# Deleted folder: 5112
# Deleted folder: 5116
# Deleted folder: 5117
# Deleted folder: 5119
# Deleted folder: 5121
# Deleted folder: 5122
# Deleted folder: 5123
# Deleted folder: 5125
# Deleted folder: 5126
# Deleted folder: 5128
# Deleted folder: 5129
# Deleted folder: 5130
# Deleted folder: 5133
# Deleted folder: 5139
# Deleted folder: 5140
# Deleted folder: 5142
# Deleted folder: 5143
# Deleted folder: 5144
# Deleted folder: 5145
# Deleted folder: 5146
# Deleted folder: 5147
# Deleted folder: 5149
# Deleted folder: 515
# Deleted folder: 5151
# Deleted folder: 5158
# Deleted folder: 5159
# Deleted folder: 5160
# Deleted folder: 5161
# Deleted folder: 5162
# Deleted folder: 5164
# Deleted folder: 5165
# Deleted folder: 5167
# Deleted folder: 5168
# Deleted folder: 5172
# Deleted folder: 5173
# Deleted folder: 5174
# Deleted folder: 5175
# Deleted folder: 5176
# Deleted folder: 5177
# Deleted folder: 5178
# Deleted folder: 5179
# Deleted folder: 518
# Deleted folder: 5180
# Deleted folder: 5181
# Deleted folder: 5186
# Deleted folder: 5187
# Deleted folder: 5188
# Deleted folder: 5189
# Deleted folder: 5190
# Deleted folder: 5192
# Deleted folder: 5193
# Deleted folder: 5194
# Deleted folder: 5195
# Deleted folder: 5196
# Deleted folder: 5197
# Deleted folder: 5198
# Deleted folder: 5199
# Deleted folder: 5200
# Deleted folder: 5201
# Deleted folder: 5202
# Deleted folder: 5203
# Deleted folder: 5206
# Deleted folder: 5208
# Deleted folder: 5209
# Deleted folder: 521
# Deleted folder: 5211
# Deleted folder: 5212
# Deleted folder: 5213
# Deleted folder: 5215
# Deleted folder: 5218
# Deleted folder: 522
# Deleted folder: 5220
# Deleted folder: 5224
# Deleted folder: 5225
# Deleted folder: 5227
# Deleted folder: 5229
# Deleted folder: 523
# Deleted folder: 5230
# Deleted folder: 5231
# Deleted folder: 5232
# Deleted folder: 5233
# Deleted folder: 5235
# Deleted folder: 5236
# Deleted folder: 5238
# Deleted folder: 5239
# Deleted folder: 524
# Deleted folder: 5240
# Deleted folder: 5242
# Deleted folder: 5243
# Deleted folder: 5244
# Deleted folder: 525
# Deleted folder: 5250
# Deleted folder: 5254
# Deleted folder: 5256
# Deleted folder: 5257
# Deleted folder: 5259
# Deleted folder: 5261
# Deleted folder: 5263
# Deleted folder: 5264
# Deleted folder: 5265
# Deleted folder: 5266
# Deleted folder: 5267
# Deleted folder: 5269
# Deleted folder: 5271
# Deleted folder: 5277
# Deleted folder: 5279
# Deleted folder: 5282
# Deleted folder: 5284
# Deleted folder: 5285
# Deleted folder: 5286
# Deleted folder: 5287
# Deleted folder: 5289
# Deleted folder: 5290
# Deleted folder: 5292
# Deleted folder: 5293
# Deleted folder: 5294
# Deleted folder: 5297
# Deleted folder: 5298
# Deleted folder: 5300
# Deleted folder: 5301
# Deleted folder: 5302
# Deleted folder: 5304
# Deleted folder: 5307
# Deleted folder: 5308
# Deleted folder: 5309
# Deleted folder: 5310
# Deleted folder: 5311
# Deleted folder: 5312
# Deleted folder: 5313
# Deleted folder: 5314
# Deleted folder: 5321
# Deleted folder: 5322
# Deleted folder: 5323
# Deleted folder: 5325
# Deleted folder: 5328
# Deleted folder: 5329
# Deleted folder: 5331
# Deleted folder: 5332
# Deleted folder: 5333
# Deleted folder: 5334
# Deleted folder: 5336
# Deleted folder: 5338
# Deleted folder: 5339
# Deleted folder: 5340
# Deleted folder: 5341
# Deleted folder: 5342
# Deleted folder: 5343
# Deleted folder: 5344
# Deleted folder: 5346
# Deleted folder: 5347
# Deleted folder: 5349
# Deleted folder: 5350
# Deleted folder: 5352
# Deleted folder: 5353
# Deleted folder: 5357
# Deleted folder: 5358
# Deleted folder: 5359
# Deleted folder: 536
# Deleted folder: 5365
# Deleted folder: 5366
# Deleted folder: 5368
# Deleted folder: 5369
# Deleted folder: 537
# Deleted folder: 5371
# Deleted folder: 5372
# Deleted folder: 5375
# Deleted folder: 5376
# Deleted folder: 5377
# Deleted folder: 5378
# Deleted folder: 5379
# Deleted folder: 538
# Deleted folder: 5380
# Deleted folder: 5381
# Deleted folder: 5382
# Deleted folder: 5383
# Deleted folder: 5384
# Deleted folder: 5385
# Deleted folder: 5386
# Deleted folder: 5387
# Deleted folder: 5388
# Deleted folder: 5389
# Deleted folder: 5391
# Deleted folder: 5394
# Deleted folder: 5395
# Deleted folder: 5396
# Deleted folder: 5397
# Deleted folder: 5399
# Deleted folder: 5400
# Deleted folder: 5402
# Deleted folder: 5403
# Deleted folder: 5404
# Deleted folder: 5405
# Deleted folder: 5406
# Deleted folder: 5407
# Deleted folder: 5408
# Deleted folder: 5409
# Deleted folder: 5410
# Deleted folder: 5411
# Deleted folder: 554
# Deleted folder: 555
# Deleted folder: 556
# Deleted folder: 557
# Deleted folder: 558
# Deleted folder: 559
# Deleted folder: 56
# Deleted folder: 560
# Deleted folder: 561
# Deleted folder: 57
# Deleted folder: 574
# Deleted folder: 575
# Deleted folder: 58
# Deleted folder: 585
# Deleted folder: 586
# Deleted folder: 587
# Deleted folder: 591
# Deleted folder: 595
# Deleted folder: 597
# Deleted folder: 598
# Deleted folder: 599
# Deleted folder: 6
# Deleted folder: 60
# Deleted folder: 600
# Deleted folder: 601
# Deleted folder: 602
# Deleted folder: 603
# Deleted folder: 604
# Deleted folder: 605
# Deleted folder: 606
# Deleted folder: 607
# Deleted folder: 608
# Deleted folder: 609
# Deleted folder: 61
# Deleted folder: 611
# Deleted folder: 612
# Deleted folder: 613
# Deleted folder: 614
# Deleted folder: 615
# Deleted folder: 616
# Deleted folder: 617
# Deleted folder: 619
# Deleted folder: 620
# Deleted folder: 621
# Deleted folder: 622
# Deleted folder: 623
# Deleted folder: 624
# Deleted folder: 625
# Deleted folder: 626
# Deleted folder: 629
# Deleted folder: 63
# Deleted folder: 631
# Deleted folder: 633
# Deleted folder: 634
# Deleted folder: 635
# Deleted folder: 636
# Deleted folder: 638
# Deleted folder: 639
# Deleted folder: 64
# Deleted folder: 640
# Deleted folder: 641
# Deleted folder: 642
# Deleted folder: 643
# Deleted folder: 65
# Deleted folder: 650
# Deleted folder: 651
# Deleted folder: 653
# Deleted folder: 654
# Deleted folder: 655
# Deleted folder: 656
# Deleted folder: 657
# Deleted folder: 658
# Deleted folder: 660
# Deleted folder: 661
# Deleted folder: 662
# Deleted folder: 663
# Deleted folder: 664
# Deleted folder: 665
# Deleted folder: 666
# Deleted folder: 667
# Deleted folder: 669
# Deleted folder: 673
# Deleted folder: 676
# Deleted folder: 678
# Deleted folder: 68
# Deleted folder: 680
# Deleted folder: 683
# Deleted folder: 684
# Deleted folder: 685
# Deleted folder: 686
# Deleted folder: 687
# Deleted folder: 688
# Deleted folder: 689
# Deleted folder: 69
# Deleted folder: 690
# Deleted folder: 692
# Deleted folder: 693
# Deleted folder: 699
# Deleted folder: 7
# Deleted folder: 700
# Deleted folder: 701
# Deleted folder: 702
# Deleted folder: 703
# Deleted folder: 704
# Deleted folder: 705
# Deleted folder: 708
# Deleted folder: 709
# Deleted folder: 710
# Deleted folder: 711
# Deleted folder: 712
# Deleted folder: 713
# Deleted folder: 714
# Deleted folder: 715
# Deleted folder: 716
# Deleted folder: 717
# Deleted folder: 718
# Deleted folder: 719
# Deleted folder: 725
# Deleted folder: 729
# Deleted folder: 730
# Deleted folder: 731
# Deleted folder: 732
# Deleted folder: 733
# Deleted folder: 734
# Deleted folder: 735
# Deleted folder: 736
# Deleted folder: 737
# Deleted folder: 738
# Deleted folder: 739
# Deleted folder: 740
# Deleted folder: 741
# Deleted folder: 744
# Deleted folder: 745
# Deleted folder: 746
# Deleted folder: 748
# Deleted folder: 75
# Deleted folder: 750
# Deleted folder: 751
# Deleted folder: 752
# Deleted folder: 754
# Deleted folder: 755
# Deleted folder: 757
# Deleted folder: 759
# Deleted folder: 760
# Deleted folder: 762
# Deleted folder: 763
# Deleted folder: 764
# Deleted folder: 765
# Deleted folder: 766
# Deleted folder: 769
# Deleted folder: 77
# Deleted folder: 770
# Deleted folder: 772
# Deleted folder: 776
# Deleted folder: 778
# Deleted folder: 78
# Deleted folder: 781
# Deleted folder: 782
# Deleted folder: 783
# Deleted folder: 785
# Deleted folder: 786
# Deleted folder: 787
# Deleted folder: 788
# Deleted folder: 79
# Deleted folder: 791
# Deleted folder: 792
# Deleted folder: 797
# Deleted folder: 798
# Deleted folder: 80
# Deleted folder: 803
# Deleted folder: 806
# Deleted folder: 807
# Deleted folder: 811
# Deleted folder: 813
# Deleted folder: 814
# Deleted folder: 816
# Deleted folder: 818
# Deleted folder: 82
# Deleted folder: 820
# Deleted folder: 822
# Deleted folder: 823
# Deleted folder: 824
# Deleted folder: 825
# Deleted folder: 829
# Deleted folder: 83
# Deleted folder: 830
# Deleted folder: 831
# Deleted folder: 832
# Deleted folder: 833
# Deleted folder: 835
# Deleted folder: 836
# Deleted folder: 837
# Deleted folder: 838
# Deleted folder: 839
# Deleted folder: 841
# Deleted folder: 842
# Deleted folder: 845
# Deleted folder: 847
# Deleted folder: 848
# Deleted folder: 849
# Deleted folder: 850
# Deleted folder: 851
# Deleted folder: 853
# Deleted folder: 854
# Deleted folder: 855
# Deleted folder: 856
# Deleted folder: 857
# Deleted folder: 859
# Deleted folder: 862
# Deleted folder: 863
# Deleted folder: 864
# Deleted folder: 865
# Deleted folder: 866
# Deleted folder: 868
# Deleted folder: 87
# Deleted folder: 870
# Deleted folder: 871
# Deleted folder: 872
# Deleted folder: 873
# Deleted folder: 874
# Deleted folder: 875
# Deleted folder: 876
# Deleted folder: 877
# Deleted folder: 878
# Deleted folder: 880
# Deleted folder: 881
# Deleted folder: 884
# Deleted folder: 886
# Deleted folder: 89
# Deleted folder: 899
# Deleted folder: 9
# Deleted folder: 90
# Deleted folder: 900
# Deleted folder: 901
# Deleted folder: 904
# Deleted folder: 905
# Deleted folder: 906
# Deleted folder: 907
# Deleted folder: 908
# Deleted folder: 909
# Deleted folder: 912
# Deleted folder: 918
# Deleted folder: 919
# Deleted folder: 92
# Deleted folder: 921
# Deleted folder: 922
# Deleted folder: 923
# Deleted folder: 924
# Deleted folder: 925
# Deleted folder: 926
# Deleted folder: 927
# Deleted folder: 929
# Deleted folder: 93
# Deleted folder: 930
# Deleted folder: 931
# Deleted folder: 932
# Deleted folder: 933
# Deleted folder: 934
# Deleted folder: 935
# Deleted folder: 936
# Deleted folder: 937
# Deleted folder: 938
# Deleted folder: 939
# Deleted folder: 94
# Deleted folder: 940
# Deleted folder: 941
# Deleted folder: 944
# Deleted folder: 945
# Deleted folder: 946
# Deleted folder: 95
# Deleted folder: 952
# Deleted folder: 953
# Deleted folder: 955
# Deleted folder: 956
# Deleted folder: 957
# Deleted folder: 958
# Deleted folder: 959
# Deleted folder: 96
# Deleted folder: 963
# Deleted folder: 964
# Deleted folder: 965
# Deleted folder: 966
# Deleted folder: 967
# Deleted folder: 968
# Deleted folder: 969
# Deleted folder: 97
# Deleted folder: 970
# Deleted folder: 971
# Deleted folder: 972
# Deleted folder: 973
# Deleted folder: 974
# Deleted folder: 975
# Deleted folder: 976
# Deleted folder: 978
# Deleted folder: 98
# Deleted folder: 981
# Deleted folder: 982
# Deleted folder: 983
# Deleted folder: 985
# Deleted folder: 986
# Deleted folder: 987
# Deleted folder: 988
# Deleted folder: 99
# Deleted folder: 991
# Deleted folder: 992
# Deleted folder: 993
# Deleted folder: 994
# Deleted folder: 995
# Cleanup complete.

# %%
import json
import os
import logging
import uuid
import asyncio
from azure.identity.aio import DefaultAzureCredential
from azure.storage.blob.aio import BlobServiceClient
import asyncio
from dotenv import load_dotenv
load_dotenv()


async def get_blob_service_client():
    credential = DefaultAzureCredential()
    account_url = f"https://{os.getenv('AZURE_STORAGE_ACCOUNT_NAME')}.blob.core.windows.net"
    # Create BlobServiceClient using the credential
    blob_service_client = BlobServiceClient(account_url, credential=credential)
    return blob_service_client, credential

async def list_blobs_with_metadata(blob_service_client, credential, container_name):   
    container_client = blob_service_client.get_container_client(container_name)
    
    blob_list = []
    tasks = []
    # Define a semaphore to limit the number of concurrent operations
    semaphore = asyncio.Semaphore(15)  # Adjust the value as needed

    async for blob in container_client.list_blobs():
        task = asyncio.create_task(process_blob(blob, container_client, semaphore))
        tasks.append(task)
    
    # Gather results concurrently
    blob_list = await asyncio.gather(*tasks)
    return blob_list

async def process_blob(blob, container_client, semaphore):
    async with semaphore:
        metadata_ = {
            'name': blob.name,
            'url': None,
            'uploaded_by': None,
            'type': None,
            'uploaded_at': blob.last_modified.strftime("%d/%m/%Y %H:%M:%S")
        }
        
        blob_client = container_client.get_blob_client(blob)
        blob_properties = await blob_client.get_blob_properties()
        blob_metadata = blob_properties.metadata

        metadata_['url'] = blob_metadata.get('url_metadata')
        metadata_['uploaded_by'] = blob_metadata.get('uploaded_by')
        metadata_['type'] = blob_metadata.get('type')

        return metadata_

# %%
blob_service_client, credential = await get_blob_service_client() 
blob_list = await list_blobs_with_metadata(blob_service_client, credential, "training-videos-testing")

# %%
import pandas as pd

df = pd.DataFrame(blob_list)
df.to_excel('datd_index.xlsx', index=None)
